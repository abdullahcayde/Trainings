# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/Python_Projects-main/selenium_projects/selenium_06/ebay08_jazz_auto.csv'
df = pd.read_csv(path , usecols= [1,2,3,4,5,6] )
df
# Out:
#                                                 Title        Price  \
# 0                  SUCHE Honda Yazz Eleganz Automatik  15.000 € VB
# 1                                   Honda Jazz 1.4 LS      3.999 €
# 2   Honda Jazz Elegance 2. HAND NAVI KAMERA SHZ BL...     15.990 €
# 3   Honda Jazz 1.3 i-VTEC Trend CVT*SCHECKHEFT*8-F...     13.380 €
# 4                              Honda Jazz 1.3 Comfort     17.980 €
# 5                                          Auto Honda      4.700 €
# 6   Honda Jazz 1.4 Comfort| Scheckh.| TÜV NEU| Kli...      3.690 €
# 7                                   Honda Jazz 1.4 LS        999 €
# 8   Honda Jazz Trend i Multif.Lenkrad Klima CD AUX...      7.990 €
# 9                     Guten Tag ,das Auto zu verkaufe   3.500 € VB
# 10                        Honda jazz hybrid Automatik   5.800 € VB
# 11                              Honda Jazz 1.4 CVT ES      4.999 €
# 12                         Honda Jazz 1.2 Trend Klima      2.000 €
#
# ...

# %%
df['Price'] = df['Price'].str.strip()
df
# Out:
#                                                 Title        Price  \
# 0                  SUCHE Honda Yazz Eleganz Automatik  15.000 € VB
# 1                                   Honda Jazz 1.4 LS      3.999 €
# 2   Honda Jazz Elegance 2. HAND NAVI KAMERA SHZ BL...     15.990 €
# 3   Honda Jazz 1.3 i-VTEC Trend CVT*SCHECKHEFT*8-F...     13.380 €
# 4                              Honda Jazz 1.3 Comfort     17.980 €
# 5                                          Auto Honda      4.700 €
# 6   Honda Jazz 1.4 Comfort| Scheckh.| TÜV NEU| Kli...      3.690 €
# 7                                   Honda Jazz 1.4 LS        999 €
# 8   Honda Jazz Trend i Multif.Lenkrad Klima CD AUX...      7.990 €
# 9                     Guten Tag ,das Auto zu verkaufe   3.500 € VB
# 10                        Honda jazz hybrid Automatik   5.800 € VB
# 11                              Honda Jazz 1.4 CVT ES      4.999 €
# 12                         Honda Jazz 1.2 Trend Klima      2.000 €
#
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'])

# %%
df.describe()
# Out:
#            Price          Km         Year
# count  11.000000   11.000000    11.000000
# mean    4.161636  144.492818  2006.454545
# std     1.004829   68.346829     2.910795
# min     2.000000   43.000000  2002.000000
# 25%     3.745000   95.664000  2005.000000
# 50%     3.999000  161.753000  2006.000000
# 75%     4.845000  178.683000  2008.500000
# max     5.800000  280.000000  2012.000000

# %%
df.Km[0] -1
# Out:
# 141.0
