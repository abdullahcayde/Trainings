# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore')

sns.set_theme(style="whitegrid")

# %%
# 01 - sildik
com.samsung.shealth.tracker.pedometer_day_summary,6212007,5

# %%
# 02 - Read File

day_summary = pd.read_csv('/Users/macbook/Desktop/projects/Github_Repositories/Trainings/Saumsung_Health_Files/com.samsung.shealth.tracker.pedometer_day_summary.202206260503.csv')
df = day_summary.copy()
df.head()
# Out:
#                                              step_count  binning_data  \
# 7280  66f11378-3936-48b6-b9b8-278dab5c7615.binning_d...       4570966
# 7280  8d23ec26-7ceb-4b3e-916a-6b120d3caf6b.binning_d...       4571024
# 864   eed8728c-aa5d-4122-9c79-170fd322158d.binning_d...        471977
# 1894  946f6291-cca8-4c09-b4de-776e318766d6.binning_d...       1188037
# 864   20a59717-3e69-47bb-ab74-510c3951fd0c.binning_d...        471991
#
#       active_time  recommendation           run_step_count  \
# 7280         6000              88  2020-06-03 22:00:00.231
# 7280         6000              88  2020-06-03 20:03:18.442
# 864          6000               0  2020-06-04 22:00:00.575
# 1894         6000               0  2020-06-06 22:17:35.483
# 864          6000               0  2020-06-04 13:36:19.096
#
#                       update_time      source_package_name  \
# 7280  com.sec.android.app.shealth  2020-06-03 22:00:00.231
# 7280  com.sec.android.app.shealth  2020-06-03 08:16:59.509
# ...

# %%
com.samsung.shealth.tracker.pedometer_day_summary.202206260503
