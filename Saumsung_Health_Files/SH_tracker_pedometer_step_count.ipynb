# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.simplefilter(action='ignore')

#Butun kolon ve satirlari gormek icin
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

#virgulden sonra gösterilecek olan sayı 2 basamak olarak ayarlanıyor.
#pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Grafik Ayarlari
# Arka tarf cizgili olur
sns.set_theme(style="whitegrid")

# %%
# 01 - Dosya calismadi asagidakiler dosayadan silin

com.samsung.shealth.tracker.pedometer_step_count,6212007,2

# %%
# 02 - Read File

step_counter = pd.read_csv('/Users/macbook/Desktop/projects/Github_Repositories/Trainings/Saumsung_Health_Files/com.samsung.shealth.tracker.pedometer_step_count.202206260503.csv')
df = step_counter.copy()
df.head()
# Out:
#        duration  version_code  run_step                walk_step  \
# 7778          4             0        10  2022-05-22 03:20:00.000
# 27111         4             0        42  2022-05-22 03:45:00.000
# 15241         4             0        38  2022-05-22 03:56:00.000
# 9993          4             0        21  2022-05-22 07:40:00.000
# 6752          4             0        12  2022-05-22 07:52:00.000
#
#        com.samsung.health.step_count.start_time  \
# 7778                                   230002.0
# 27111                                  230002.0
# 15241                                  230002.0
# 9993                                   230002.0
# 6752                                   230002.0
#
#        com.samsung.health.step_count.sample_position_type  \
# 7778                                                 NaN
# 27111                                                NaN
# 15241                                                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10441 entries, 7778 to 9190
# Data columns (total 18 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   duration                                            10441 non-null  int64
#  1   version_code                                        10441 non-null  int64
#  2   run_step                                            10441 non-null  int64
#  3   walk_step                                           10441 non-null  object
#  4   com.samsung.health.step_count.start_time            7529 non-null   float64
#  5   com.samsung.health.step_count.sample_position_type  0 non-null      float64
#  6   com.samsung.health.step_count.custom                10441 non-null  object
#  7   com.samsung.health.step_count.update_time           10441 non-null  object
# ...

# %%
df.describe().T
# Out:
#                                                       count           mean  \
# duration                                            10441.0       4.000000
# version_code                                        10441.0       0.393545
# run_step                                            10441.0      36.197586
# com.samsung.health.step_count.start_time             7529.0  230002.000000
# com.samsung.health.step_count.sample_position_type      0.0            NaN
# com.samsung.health.step_count.create_time           10441.0      36.852600
# com.samsung.health.step_count.count                 10441.0       1.343567
# com.samsung.health.step_count.speed                 10441.0      28.198024
# com.samsung.health.step_count.distance              10441.0       1.490855
# com.samsung.health.step_count.datauuid                  0.0            NaN
#
#                                                           std       min  \
# ...

# %%
df.columns
# Out:
# Index(['duration', 'version_code', 'run_step', 'walk_step',
#        'com.samsung.health.step_count.start_time',
#        'com.samsung.health.step_count.sample_position_type',
#        'com.samsung.health.step_count.custom',
#        'com.samsung.health.step_count.update_time',
#        'com.samsung.health.step_count.create_time',
#        'com.samsung.health.step_count.count',
#        'com.samsung.health.step_count.speed',
#        'com.samsung.health.step_count.distance',
#        'com.samsung.health.step_count.calorie',
#        'com.samsung.health.step_count.time_offset',
#        'com.samsung.health.step_count.deviceuuid',
#        'com.samsung.health.step_count.pkg_name',
#        'com.samsung.health.step_count.end_time',
#        'com.samsung.health.step_count.datauuid'],
#       dtype='object')

# %%
# 03 - Kolon adi degistirme (com.samsung.health. silindi)

df.columns = df.columns.str.replace('com.samsung.health.', '')
df.columns
# Out:
# Index(['duration', 'version_code', 'run_step', 'walk_step',
#        'step_count.start_time', 'step_count.sample_position_type',
#        'step_count.custom', 'step_count.update_time', 'step_count.create_time',
#        'step_count.count', 'step_count.speed', 'step_count.distance',
#        'step_count.calorie', 'step_count.time_offset', 'step_count.deviceuuid',
#        'step_count.pkg_name', 'step_count.end_time', 'step_count.datauuid'],
#       dtype='object')

# %%
df.head()
# Out:
#        duration  version_code  run_step                walk_step  \
# 7778          4             0        10  2022-05-22 03:20:00.000
# 27111         4             0        42  2022-05-22 03:45:00.000
# 15241         4             0        38  2022-05-22 03:56:00.000
# 9993          4             0        21  2022-05-22 07:40:00.000
# 6752          4             0        12  2022-05-22 07:52:00.000
#
#        step_count.start_time  step_count.sample_position_type  \
# 7778                230002.0                              NaN
# 27111               230002.0                              NaN
# 15241               230002.0                              NaN
# 9993                230002.0                              NaN
# 6752                230002.0                              NaN
#
#              step_count.custom   step_count.update_time  \
# 7778   2022-05-22 03:31:51.290  2022-05-22 03:31:51.289
# 27111  2022-05-22 03:55:01.186  2022-05-22 03:55:01.186
# ...

# %%
pd.set_option('display.max_row', 10)
df.walk_step[0:70]
# Out:
# 7778     2022-05-22 03:20:00.000
# 27111    2022-05-22 03:45:00.000
# 15241    2022-05-22 03:56:00.000
# 9993     2022-05-22 07:40:00.000
# 6752     2022-05-22 07:52:00.000
#                   ...
# 60000    2022-05-22 14:24:00.000
# 8524     2022-05-22 10:12:00.000
# 6176     2022-05-22 11:24:00.000
# 37182    2022-05-22 14:20:00.000
# 520      2022-05-22 07:44:00.000
# Name: walk_step, Length: 70, dtype: object

# %%
df.iloc[:][['duration', 'walk_step']]
# Out:
#        duration                walk_step
# 7778          4  2022-05-22 03:20:00.000
# 27111         4  2022-05-22 03:45:00.000
# 15241         4  2022-05-22 03:56:00.000
# 9993          4  2022-05-22 07:40:00.000
# 6752          4  2022-05-22 07:52:00.000
# ...         ...                      ...
# 8290          4  2022-06-25 08:03:00.000
# 21090         4  2022-06-25 08:04:00.000
# 12390         4  2022-06-25 08:06:00.000
# 25409         4  2022-06-25 08:08:00.000
# 9190          4  2022-06-25 08:11:00.000
#
# [10441 rows x 2 columns]

# %%
df.walk_step.value_counts()
# Out:
# 2022-06-18 08:43:00.000    2
# 2022-06-04 15:45:00.000    2
# 2022-06-17 18:00:00.000    2
# 2022-06-04 15:07:00.000    2
# 2022-06-17 17:59:00.000    2
#                           ..
# 2022-06-04 19:43:00.000    1
# 2022-06-05 11:53:00.000    1
# 2022-06-05 14:48:00.000    1
# 2022-06-04 19:35:00.000    1
# 2022-06-25 08:08:00.000    1
# Name: walk_step, Length: 8157, dtype: int64

# %%
df.duration.value_counts()
# Out:
# 4    10441
# Name: duration, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10441 entries, 7778 to 9190
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   duration                         10441 non-null  int64
#  1   version_code                     10441 non-null  int64
#  2   run_step                         10441 non-null  int64
#  3   walk_step                        10441 non-null  object
#  4   step_count.start_time            7529 non-null   float64
#  5   step_count.sample_position_type  0 non-null      float64
#  6   step_count.custom                10441 non-null  object
#  7   step_count.update_time           10441 non-null  object
#  8   step_count.create_time           10441 non-null  int64
#  9   step_count.count                 10441 non-null  float64
#  10  step_count.speed                 10441 non-null  float64
#  11  step_count.distance              10441 non-null  float64
# ...

# %%
df.head()
# Out:
#        duration  version_code  run_step                walk_step  \
# 7778          4             0        10  2022-05-22 03:20:00.000
# 27111         4             0        42  2022-05-22 03:45:00.000
# 15241         4             0        38  2022-05-22 03:56:00.000
# 9993          4             0        21  2022-05-22 07:40:00.000
# 6752          4             0        12  2022-05-22 07:52:00.000
#
#        step_count.start_time  step_count.sample_position_type  \
# 7778                230002.0                              NaN
# 27111               230002.0                              NaN
# 15241               230002.0                              NaN
# 9993                230002.0                              NaN
# 6752                230002.0                              NaN
#
#              step_count.custom   step_count.update_time  \
# 7778   2022-05-22 03:31:51.290  2022-05-22 03:31:51.289
# 27111  2022-05-22 03:55:01.186  2022-05-22 03:55:01.186
# ...

# %%
len(df.columns)
# Out:
# 18

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.set_option('display.max_colwidth', 100)
df.head()
# Out:
#        duration  version_code  run_step                walk_step  \
# 7778          4             0        10  2022-05-22 03:20:00.000
# 27111         4             0        42  2022-05-22 03:45:00.000
# 15241         4             0        38  2022-05-22 03:56:00.000
# 9993          4             0        21  2022-05-22 07:40:00.000
# 6752          4             0        12  2022-05-22 07:52:00.000
#
#        step_count.start_time  step_count.sample_position_type  \
# 7778                230002.0                              NaN
# 27111               230002.0                              NaN
# 15241               230002.0                              NaN
# 9993                230002.0                              NaN
# 6752                230002.0                              NaN
#
#              step_count.custom   step_count.update_time  \
# 7778   2022-05-22 03:31:51.290  2022-05-22 03:31:51.289
# 27111  2022-05-22 03:55:01.186  2022-05-22 03:55:01.186
# ...

# %%
sns.lmplot(x= 'step_count.distance', y= 'step_count.speed', data= df);

# %%
sns.lmplot(x= 'step_count.count', y= 'step_count.distance', data= df);

# %%
sns.lmplot(x= 'step_count.distance', y= 'step_count.speed', hue= 'step_count.start_time', data= df);
