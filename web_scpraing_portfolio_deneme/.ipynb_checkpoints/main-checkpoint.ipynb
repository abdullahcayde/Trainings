# %%
import time
import logging
import numpy as np
import pandas as pd
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import psycopg2
from sqlalchemy import create_engine

import warnings
warnings.simplefilter(action='ignore')

# Sleep function 
def sleep(x):
    time.sleep(x)

# Wait for a certain measure of time before throwing an exception
def wait(x):
    driver.implicitly_wait(x)

# Click Function
def click_bann_byID(ID):
    actions = ActionChains(driver)
    akzeptieren = driver.find_element(By.ID, ID)
    actions.click(akzeptieren).perform()
    wait(10)
    sleep(0.5)


# Find Element Function
def find_element(H):
    header = driver.find_elements(By.CLASS_NAME, H)
    list_header = [title.text for title in header]
    return list_header


# Find Elements Function
def find_elements_HPCO(H,P,C,O):
    header = driver.find_elements(By.CLASS_NAME, H)
    publish = driver.find_elements(By.CLASS_NAME, P)
    company = driver.find_elements(By.CLASS_NAME, C)
    ort = driver.find_elements(By.CLASS_NAME, O) 

    list_header = [title.text for title in header]
    list_publish = [pub.text for pub in publish]
    list_company = [comp.text for comp in company]
    list_ort = [o.text for o in ort]
    return list_header, list_publish, list_company, list_ort

def log(message):
    timestamp_format = '%Y-%h-%d-%H:%M:%S' # Year-Monthname-Day-Hour-Minute-Second
    now = datetime.now() # get current timestamp
    timestamp = now.strftime(timestamp_format)
    with open("logfile.txt","a") as f:
        f.write(timestamp + ',' + message + '\n')

logging.basicConfig(level=logging.DEBUG, filename='logs.log', filemode='a',
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    datefmt="%Y-%m-%d %H:%M:%S",)

logging.debug('debug')
logging.info('info')
logging.warning('warning')
logging.error('error', exc_info=True)
logging.critical('critical')

# %%
print('---------------------- StepStone Job Searching Selenium Project ----------------------')
start=datetime.now()
log('start_stepstone')
# Link Descriptions
link_original_stepstone = 'https://www.stepstone.de/jobs/data-analyst/in-rietberg?radius=50&page=2'

website_name = 'stepstone'
job_name = 'Data Engineer'
ort_ = 'Rietberg'
radius = 100
page_number = 1

#  1 - Create Driver
Path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/web_scpraing_portfolio_deneme/chromedriver'
driver = webdriver.Chrome(Path)
print('Create Driver')


#  2 - Go to Website
job_link = job_name.replace(' ', '-').lower()
ort_link = ort_.lower()
link = f'https://www.stepstone.de/jobs/{job_link}/in-{ort_link}?radius={radius}&page={page_number}&sort=2&action=sort_publish'

driver.get(link)
wait(5)
sleep(2)
print('Go to Website')
#  3 - ActionChain Object created
# 3.1 - Click Banned Accept
ID = 'ccmgt_explicit_accept'
click_bann_byID(ID)
print('Banned')

# 4 -  Take Infos from Page
# 4.1 - Headers, Publish_Time ,Company, City
H, P, C, O = ('res-29pyh9', 'res-rf8k2x', 'res-hbyqhf', 'res-1wf9en7')
list_header, list_publish, list_company, list_ort = find_elements_HPCO(H,P,C,O)

# 4.2 - Description and Page number of results
description = driver.find_elements(By.CLASS_NAME, 'res-17md5or')



# 4.3 - Get Links 'res-1dwe62q'
list_link01  = driver.find_elements(By.CLASS_NAME, 'res-1dwe62q')
list_link = [link.get_attribute('href') for link in list_link01]

# 4.4 - Get Texts for each finding
list_description = [des.text for des in description]
print('Header',len(list_header), 'Publish',len(list_publish), 'Company',len(list_company[1:]), 'Ort',len(list_ort), 'Desc', len(list_description), 'Link',len(list_link))


# 4.6 - DataFrame df
d = dict(job_title=np.array(list_header), publish=np.array(list_publish), company=np.array(list_company[1:]), city=np.array(list_ort) , description=np.array(list_description), link=np.array(list_link))
df01 = pd.DataFrame.from_dict(d, orient='index')
df01 = df01.T

# 5.1 - Save Data as csv 
print(f'DataFrame End : {df01.shape}')
df01['website'] = website_name
time_ = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
df01['date'] = time_
df01['search_title'] = job_name

# 6 - Quit
end =datetime.now() 
print('Code Runned No Problem')
log('end_stepstone')
print(f'Time = {end - start}')
sleep(0.5)
driver.quit()
df01.head(2)
# Out:
# ---------------------- StepStone Job Searching Selenium Project ----------------------
# /var/folders/ht/tcz99qld7qz6stv5g043rfyc0000gn/T/ipykernel_18033/2042400451.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(Path)
# Create Driver
# Go to Website
# Banned
# Header 25 Publish 25 Company 24 Ort 25 Desc 25 Link 25
# DataFrame End : (25, 6)
# Code Runned No Problem
# Time = 0:00:18.318558
#                         job_title      publish  \
# 0  (Senior) Data Engineer (m/f/d)    vor 1 Tag
# 1        IT-Data Engineer (m/w/d)  vor 4 Tagen
#
#                                              company  \
# 0            Kasseler Verkehrs- und Versorgungs GmbH
# 1  CTH Gesellschaft für Entscheidungs- und Inform...
#
#                         city  \
# 0  Berlin, Baden-Baden, Verl
# 1                     Kassel
#
#                                          description  \
# 0  Our ambition is higher and now we have a great...
# 1  Als IT-Data Engineer (m/w/d) führen Sie Datenp...
#
#                                                 link    website  \
# 0  https://www.stepstone.de/stellenangebote--Seni...  stepstone
# 1  https://www.stepstone.de/stellenangebote--IT-D...  stepstone
#
#                   date   search_title
# 0  2023-03-14 11:41:18  Data Engineer
# 1  2023-03-14 11:41:18  Data Engineer

# %%
print('---------------------- Xing Job Searching Selenium Project ----------------------')
start=datetime.now()
log('start_xing')  
# Link Descriptions
link_original_xing = 'https://www.xing.com/jobs/search?keywords=Data%20Engineer&location=Rietberg&page=1&radius=100'

website_name = 'xing'
job_name = 'Data Engineer'
#job_name = 'Data Analyst'
#job_name = 'Data Scientist'
ort_ = 'Rietberg'
radius = 50
page_number = 1

#  1 - Create Driver
Path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/web_scpraing_portfolio_deneme/chromedriver'
driver = webdriver.Chrome(Path)

#  2 - Go to Website
job_link = job_name.replace(' ', '-').lower()
ort_link = ort_.lower()
link = f'https://www.xing.com/jobs/search?keywords=Data%20Engineer&location=Rietberg&page=1&radius=100&sort=date'

driver.get(link)
wait(10)
sleep(2)

#  3 - ActionChain Object created
# 3.1 - Click Banned Accept
ID = 'consent-accept-button'
click_bann_byID(ID)

# 4 -  Take Infos from Page
# 4.1 - Headers, Publish_Time ,Company, City
H = 'utils-line-clamp-lineClamp2-dfe26aab'
D = 'list-item-job-teaser-list-item-highlight-bb8ddbb6'
L = 'list-item-job-teaser-list-item-location-a5b28738'
ALL = 'list-item-job-teaser-list-item-listItem-f04c772e'


list_header = find_element(H)
list_description = find_element(D)
list_ort = find_element(L)
list_all = find_element(ALL)

list_publish = []
list_full_time = [] 
for i in list_all:
    date = i.split('\n')[-2]
    time_ = i.split('\n')[-3]
    list_publish.append(date)
    list_full_time.append(time_)

list_title =[]
list_company = []
n = 0
while n < len(list_header):
    list_title.append(list_header[n])
    list_company.append(list_header[n+1])
    n += 2

# 4.3 - Get Links
Link = 'list-item-job-teaser-list-item-listItem-f04c772e'
header = driver.find_elements(By.CLASS_NAME, Link)
list_link = [link.get_attribute('href') for link in header]

# 4.4 - DataFrame df
d = dict(job_title=np.array(list_title), publish=np.array(list_publish), company=np.array(list_company), city=np.array(list_ort) , description=np.array(list_description), link=np.array(list_link))
df02 = pd.DataFrame.from_dict(d, orient='index')
df02 = df02.T
df02['website'] = website_name
time_now = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
df02['date'] = time_now
df02['search_title'] = job_name


list_of_list = [list_header, list_description, list_ort, list_publish, list_link]
print([len(i) for i in list_of_list])

sleep(2)
driver.quit()
print('Finish', time_now)
log('end_xing') 

df02.head(2)
# Out:
# ---------------------- Xing Job Searching Selenium Project ----------------------
# /var/folders/ht/tcz99qld7qz6stv5g043rfyc0000gn/T/ipykernel_18033/2509655784.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(Path)
# [40, 18, 20, 20, 20]
# Finish 2023-03-14 11:41:30
#                job_title        publish  \
# 0  Data Engineer (m/w/d)  Vor 2 Stunden
# 1         Data Architect  Vor 4 Stunden
#
#                                            company         city  \
# 0  Computer Futures, ein Geschäftszweig von SThree      Münster
# 1                                 Computer Futures  Holzwickede
#
#                                          description  \
# 0  Engineering, Datenmanagement oder einer verwan...
# 1  Data Archtitect (m/w/d) in unbefristeter Festa...
#
#                                                 link website  \
# 0  https://www.xing.com/jobs/muenster-data-engine...    xing
# 1  https://www.xing.com/jobs/holzwickede-data-arc...    xing
#
#                   date   search_title
# 0  2023-03-14 11:41:30  Data Engineer
# 1  2023-03-14 11:41:30  Data Engineer

# %%
print('--------------------------------------- Connect to Database ---------------------------------------')

conn = psycopg2.connect(database="JOB",
						user='postgres', password=1984,
						host='127.0.0.1', port='5432'
)

conn.autocommit = True
cursor = conn.cursor()

log('connected_database')

sql = '''CREATE TABLE IF NOT EXISTS daily(job_title text NOT NULL,\
publish varchar(30),\
company text,\
city varchar(200),\
description text,\
link text,\
website varchar(30),\
date timestamp,\
search_title varchar(20));'''

cursor.execute(sql)


# connection string: driver://username:password@server/database
engine = create_engine('postgresql+psycopg2://postgres:1984@localhost/JOB')

#  Note:  if_exists can be append, replace, fail.  
df01.to_sql('daily', engine, if_exists='append', index = False)
df02.to_sql('daily', engine, if_exists='append', index = False)


sql2 = '''select company from dataeng Where publish LIKE '%hours%' '''
cursor.execute(sql2)
for i in cursor.fetchall():
	print(i)

conn.commit()
log('finish_all') 
conn.close()

path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/web_scpraing_portfolio_deneme'
#df01.to_csv(f'{path}/{job_name}.csv', header=True) >> First time
df01.to_csv(f'{path}/{job_name}.csv', mode='a', header=False)
df02.to_csv(f'{path}/{job_name}.csv', mode='a', header=False)
# Out:
# --------------------------------------- Connect to Database ---------------------------------------
# ('Brunel',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Campusjäger by Workwise',)
# ('Vesterling AG',)

# %%
pd.concat([df01, df02], axis=0)
# Out:
#                                             job_title         publish  \
# 0                      (Senior) Data Engineer (m/f/d)       vor 1 Tag
# 1                            IT-Data Engineer (m/w/d)     vor 4 Tagen
# 2                        Junior Data Engineer (m/w/d)     vor 5 Tagen
# 3                                 Data Expert (m/w/d)     vor 6 Tagen
# 4                             Client Engineer (m/w/d)     vor 6 Tagen
# 5                      Data Engineer DWH / BI (m/w/d)     vor 1 Woche
# 6               Data Integration Engineer (m/w/d) EDI     vor 1 Woche
# 7   Data Engineer / Data Architect (m/w/d) Vollzei...     vor 1 Woche
# 8                               Data Engineer (m/w/d)     vor 1 Woche
# 9                    Data Governance Engineer (m/f/d)     vor 1 Woche
# 10                              Data Engineer (m/w/d)    vor 2 Wochen
# 11  (Senior) Consultant Data Engineer SAS (all gen...    vor 2 Wochen
# 12                       Data Architect (all genders)    vor 2 Wochen
# 13  (Senior) Associate Data Validation Teilzeit/Vo...    vor 3 Wochen
# 14  Cloud Architect / Cloud Data Engineer / DevOps...    vor 3 Wochen
# 15                  Process- & Data Architect (d/m/w)       vor 1 Tag
# 16  Data Scientist (m/w/d) Application / Support (...       vor 1 Tag
# 17  Data Scientist (m/w/d) Application / (Data Ana...       vor 1 Tag
# 18        DevOps Engineer (m/w/d) - DevOps Spezialist       vor 1 Tag
# 19                            DevOps Engineer (m/w/d)     vor 2 Tagen
# 20  Software Developer DevOps (m/w/d) Anwendungsen...     vor 2 Tagen
# 21                      Softwareanalyst – ERP (m/w/d)     vor 2 Tagen
# 22                Senior Enterprise Architekt (m/w/d)     vor 2 Tagen
# 23  Senior Bauingenieur / Architekt (m/w/d) Bauen ...     vor 3 Tagen
# 24                     PowerPlatform Engineer (m/w/d)     vor 3 Tagen
# 0                               Data Engineer (m/w/d)   Vor 2 Stunden
# 1                                      Data Architect   Vor 4 Stunden
# 2            Data-Engineer für Datenmigration (w/d/m)  Vor 13 Stunden
# 3                              Data Scientist (m/w/d)  Vor 19 Stunden
# 4                        Senior Data Engineer (m/w/d)  Vor 23 Stunden
# 5   Senior DevOps Engineer (m/w/d) für Dortmund, H...         Gestern
# 6   Java Backend Developer (m/w/d) für Dortmund, H...         Gestern
# 7   Data Engineer (m/w/d) für Dortmund, Hannover o...         Gestern
# 8   APEX / ORACLE Software Developer | Forms, Repo...         Gestern
# 9   APEX / ORACLE Software Developer | Forms, Repo...         Gestern
# 10  (Senior) Consultant Data Engineer SAS (all gen...         Gestern
# 11  (Senior) Software Developer C++/C#/ASP.NET (m/...         Gestern
# 12  (Senior) Machine Learning / AI Engineer (all g...     Vor 2 Tagen
# 13                  Cloud Data Engineer (all genders)     Vor 2 Tagen
# 14                  Cloud Data Engineer (all genders)     Vor 2 Tagen
# 15                  Cloud Data Engineer (all genders)     Vor 2 Tagen
# 16   AWS Experte: in (all genders) - 100% Home Office     Vor 2 Tagen
# 17                 24573 - IT System Engineer (m/w/d)     Vor 3 Tagen
# 18                              Data Engineer (m/w/d)     Vor 3 Tagen
# 19                  Logistic Process Engineer (m/f/d)     Vor 3 Tagen
#
#                                               company  \
# 0             Kasseler Verkehrs- und Versorgungs GmbH
# 1   CTH Gesellschaft für Entscheidungs- und Inform...
# 2                                        Amprion GmbH
# 3                                        Ratiodata SE
# 4                                          FALKE KGaA
# 5                                          DACHSER SE
# 6          BabyOne Franchise- und Systemzentrale GmbH
# 7                  REMONDIS IT Services GmbH & Co. KG
# 8                                             Riverty
# 9                                        Amprion GmbH
# 10                                          adesso SE
# 11                                          adesso SE
# 12                                                PwC
# 13                            saracus consulting GmbH
# 14                                    Manufactum GmbH
# 15                  Beckhoff Automation GmbH & Co. KG
# 16                  Beckhoff Automation GmbH & Co. KG
# 17                                     Ratbacher GmbH
# 18                 REMONDIS IT Services GmbH & Co. KG
# 19              EVIDENT Technology Center Europe GmbH
# 20                 REMONDIS IT Services GmbH & Co. KG
# 21                                SIGNAL IDUNA Gruppe
# 22                 ISS Facility Services Holding GmbH
# 23                                      GOLDBECK GmbH
# 24                                               None
# 0     Computer Futures, ein Geschäftszweig von SThree
# 1                                    Computer Futures
# 2                        Haufe Akademie GmbH & Co. KG
# 3                                    Computer Futures
# 4                            BRUDERKOPF GmbH & Co. KG
# 5                                           QuinScape
# 6                                           QuinScape
# 7                                           QuinScape
# 8                                       Vesterling AG
# 9                                       Vesterling AG
# 10                                          adesso SE
# 11                                         GBS Europa
# 12                                          adesso SE
# 13                                          adesso SE
# 14                                          adesso SE
# 15                                          adesso SE
# 16                            fino data services GmbH
# 17                        CEP GmbH Personalmanagement
# 18                           BRUDERKOPF GmbH & Co. KG
# 19                                    ABB Deutschland
#
#                                                  city  \
# 0                           Berlin, Baden-Baden, Verl
# 1                                              Kassel
# 2                                               Halle
# 3                                            Dortmund
# 4              Hannover (Wedemark), Münster, Duisburg
# 5                                       Schmallenberg
# 6   Berlin, Hamburg, München, Köln, Frankfurt a. M...
# 7                                             Münster
# 8                                               Lünen
# 9                           Berlin, Baden-Baden, Verl
# 10                                           Dortmund
# 11  Berlin, Köln, Hamburg, Stuttgart, Dortmund, Nü...
# 12  Berlin, Dortmund, Frankfurt, Hamburg, Köln, Mü...
# 13  Berlin, Bielefeld, Bremen, Duisburg, Düsseldor...
# 14                                     Münster, Baden
# 15                               Waltrop bei Dortmund
# 16                                               Verl
# 17                                               Verl
# 18      Bielefeld, Stuttgart, Dresden oder Regensburg
# 19                                              Lünen
# 20                                            Münster
# 21                                              Lünen
# 22                                  Dortmund, Hamburg
# 23  Dortmund, Frankfurt am Main, Hamburg, München,...
# 24                         Bielefeld, Leipzig, Plauen
# 0                                             Münster
# 1                                         Holzwickede
# 2                                           Bielefeld
# 3                                              Bochum
# 4                                            Dortmund
# 5                                            Dortmund
# 6                                            Dortmund
# 7                                            Dortmund
# 8                                            Dortmund
# 9                                              Bochum
# 10                                           Dortmund
# 11                                          Paderborn
# 12                                           Dortmund
# 13                                           Dortmund
# 14                                          Paderborn
# 15                                            Münster
# 16                                             Kassel
# 17                                           Dortmund
# 18                                             Kassel
# 19                                        Lüdenscheid
#
#                                           description  \
# 0   Our ambition is higher and now we have a great...
# 1   Als IT-Data Engineer (m/w/d) führen Sie Datenp...
# 2   Zur Unterstützung unserer Bereiche Anwendungsb...
# 3   Abhängig von der Rolle verstärken Sie unser Te...
# 4   Ratiodata SE - Die Ratiodata SE zählt zu den g...
# 5   Verstärken Sie das Team unseres Hauptsitzes am...
# 6   Berlin, Hamburg, München, Köln, Frankfurt a. M...
# 7   Mehrjährige Berufserfahrung im Data Engineerin...
# 8   In Deiner Position als Data Engineer hilfst Du...
# 9   In this role you will work directly with analy...
# 10  Aufsetzen eines umfänglichen Monitorings und B...
# 11  Basierend auf einem abgeschlossenen Studium ha...
# 12  Betreuung von internen Analytics Projekten und...
# 13  PwC * Berlin, Bielefeld, Bremen, Duisburg, Düs...
# 14  saracus ist eines der führenden unabhängigen B...
# 15  Für unsere Zentrale in Waltrop (bei Dortmund) ...
# 16  erfolgreich abgeschlossenes Studium der Fachri...
# 17  Kunden- und Applikationssupport für eine Auswa...
# 18  Dann bewirb dich jetzt als DevOps Engineer (m/...
# 19  Als DevOps Engineer unterstützt Du unsere cros...
# 20  EVIDENT Technology Center Europe GmbH * Münste...
# 21  REMONDIS IT Services GmbH & Co. KG * Lünen * F...
# 22  Kenntnisse zu modernen IT-Architekturen (Erfah...
# 23  ISS Facility Services Holding GmbH * Dortmund,...
# 24  Praktische Erfahrungen in der Anwendung der Mi...
# 0   Engineering, Datenmanagement oder einer verwan...
# 1   Data Archtitect (m/w/d) in unbefristeter Festa...
# 2   Für unser Entwickler:innen-Team suchen wir ein...
# 3   Mein langjähriger Stammkunde sucht ab sofort e...
# 4   Für ihn suchen wir einen Senior Data Engineer ...
# 5   Über uns Die QuinScape GmbH ist ein IT-Dienstl...
