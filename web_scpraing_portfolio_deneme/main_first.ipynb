# %%
import time
import logging
import numpy as np
import pandas as pd
import openpyxl
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import psycopg2
from sqlalchemy import create_engine

import warnings
warnings.simplefilter(action='ignore')

# Sleep function 
def sleep(x):
    time.sleep(x)

# Wait for a certain measure of time before throwing an exception
def wait(x):
    driver.implicitly_wait(x)

# Click Function
def click_bann_byID(ID):
    actions = ActionChains(driver)
    akzeptieren = driver.find_element(By.ID, ID)
    actions.click(akzeptieren).perform()
    wait(10)
    sleep(0.5)


# Find Element Function
def find_element(H):
    header = driver.find_elements(By.CLASS_NAME, H)
    list_header = [title.text for title in header]
    return list_header


# Find Elements Function
def find_elements_HPCO(H,P,C,O):
    header = driver.find_elements(By.CLASS_NAME, H)
    publish = driver.find_elements(By.CLASS_NAME, P)
    company = driver.find_elements(By.CLASS_NAME, C)
    ort = driver.find_elements(By.CLASS_NAME, O) 

    list_header = [title.text for title in header]
    list_publish = [pub.text for pub in publish]
    list_company = [comp.text for comp in company]
    list_ort = [o.text for o in ort]
    return list_header, list_publish, list_company, list_ort

def log(message):
    timestamp_format = '%Y-%h-%d-%H:%M:%S' # Year-Monthname-Day-Hour-Minute-Second
    now = datetime.now() # get current timestamp
    timestamp = now.strftime(timestamp_format)
    with open("logfile.txt","a") as f:
        f.write(timestamp + ',' + message + '\n')

logging.basicConfig(level=logging.DEBUG, filename='logs.log', filemode='a',
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    datefmt="%Y-%m-%d %H:%M:%S",)

logging.debug('debug')
logging.info('info')
logging.warning('warning')
logging.error('error', exc_info=True)
logging.critical('critical')

# %%
print('---------------------- StepStone Job Searching Selenium Project ----------------------')
start=datetime.now()
log('start_stepstone')


# Link Descriptions
link_original_stepstone = 'https://www.stepstone.de/jobs/data-analyst/in-rietberg?radius=50&page=2'

website_name = 'stepstone'
job_name = 'Data Engineer'
ort_ = 'Rietberg'
radius = 100


#  1 - Create Driver
Path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/web_scpraing_portfolio_deneme/chromedriver'
driver = webdriver.Chrome(Path)
print('Create Driver')

for i in range(2,7):
        page_number = i
        #  2 - Go to Website
        job_link = job_name.replace(' ', '-').lower()
        ort_link = ort_.lower()
        link = f'https://www.stepstone.de/jobs/{job_link}/in-{ort_link}?radius={radius}&page={page_number}&sort=2&action=sort_publish'

        driver.get(link)
        wait(5)
        sleep(1)
        print('Go to Website')
        #  3 - ActionChain Object created
        # 3.1 - Click Banned Accept
        if page_number == 2 :
                ID = 'ccmgt_explicit_accept'
                click_bann_byID(ID)
                print('Banned')
        else:
                print(f'Page Numer = {page_number}')
        

        # 4 -  Take Infos from Page
        # 4.1 - Headers, Publish_Time ,Company, City
        H, P, C, O = ('res-29pyh9', 'res-rf8k2x', 'res-hbyqhf', 'res-1wf9en7')
        list_header, list_publish, list_company, list_ort = find_elements_HPCO(H,P,C,O)

        # 4.2 - Description and Page number of results
        description = driver.find_elements(By.CLASS_NAME, 'res-17md5or')

        # 4.3 - Get Links 'res-1dwe62q'
        list_link01  = driver.find_elements(By.CLASS_NAME, 'res-1dwe62q')
        list_link = [link.get_attribute('href') for link in list_link01]

        # 4.4 - Get Texts for each finding
        list_description = [des.text for des in description]
        print('Header',len(list_header), 'Publish',len(list_publish), 'Company',len(list_company[1:]), 'Ort',len(list_ort), 'Desc', len(list_description), 'Link',len(list_link))


        # 4.6 - DataFrame df
        d = dict(job_title=np.array(list_header), publish=np.array(list_publish), company=np.array(list_company[1:]), city=np.array(list_ort) , description=np.array(list_description), link=np.array(list_link))
        df01 = pd.DataFrame.from_dict(d, orient='index')
        df01 = df01.T

        # 5.1 - Save Data as csv 
        print(f'DataFrame End : {df01.shape}')
        df01['website'] = website_name
        time_ = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
        df01['date'] = time_
        df01['search_title'] = job_name

        path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/web_scpraing_portfolio_deneme'
        if page_number == 2 :
                df01.to_csv(f'{path}/{job_name}_first.csv', header=True)
        else :
                df01.to_csv(f'{path}/{job_name}_first.csv', mode='a', header=False)
# 6 - Quit
end =datetime.now() 
print('Code Runned No Problem')
log('end_stepstone')
print(f'Time = {end - start}')
sleep(0.5)
driver.quit()
df01.head(2)
# Out:
# ---------------------- StepStone Job Searching Selenium Project ----------------------
# Create Driver
# Go to Website
# Banned
# Header 25 Publish 25 Company 24 Ort 25 Desc 25 Link 25
# DataFrame End : (25, 6)
# Go to Website
# Page Numer = 3
# Header 25 Publish 25 Company 24 Ort 25 Desc 25 Link 25
# DataFrame End : (25, 6)
# Go to Website
# Page Numer = 4
# Header 25 Publish 25 Company 24 Ort 25 Desc 25 Link 25
# DataFrame End : (25, 6)
# Go to Website
# Page Numer = 5
# Header 25 Publish 25 Company 24 Ort 25 Desc 25 Link 25
# DataFrame End : (25, 6)
# Go to Website
# Page Numer = 6
# Header 25 Publish 25 Company 24 Ort 25 Desc 25 Link 25
# DataFrame End : (25, 6)
# Code Runned No Problem
# Time = 0:01:24.841145
#                                            job_title      publish  \
# 0  Project Engineer / Software Developer (f/w/d) ...  vor 2 Tagen
# 1  Software Engineer | Java, Spring, GCP | Team M...  vor 2 Tagen
#
#                company                                               city  \
# 0  Otto (GmbH & Co KG)  Bremen, Augsburg, Bad Vilbel, Berlin, Dessau, ...
# 1  Otto (GmbH & Co KG)                               Hamburg, Home-Office
#
#                                          description  \
# 0  Our modular software toolkit, which is based o...
# 1  GCP Cloud (z. B. pubsub, cloudrun, cloud datas...
#
#                                                 link    website  \
# 0  https://www.stepstone.de/stellenangebote--Proj...  stepstone
# 1  https://www.stepstone.de/stellenangebote--Soft...  stepstone
#
#                   date   search_title
# 0  2023-03-14 20:30:39  Data Engineer
# 1  2023-03-14 20:30:39  Data Engineer

# %%
    print('---------------------- Xing Job Searching Selenium Project ----------------------')
start=datetime.now()
log('start_xing')  
# Link Descriptions
link_original_xing = 'https://www.xing.com/jobs/search?keywords=Data%20Engineer&location=Rietberg&page=1&radius=100'

website_name = 'xing'
job_name = 'Data Engineer'
ort_ = 'Rietberg'
radius = 100


#  1 - Create Driver
Path = '/Users/macbook/Desktop/projects/Github_Repositories/Trainings/web_scpraing_portfolio_deneme/chromedriver'
driver = webdriver.Chrome(Path)

for i in range(2,7):
        page_number = i

        #  2 - Go to Website
        job_link = job_name.replace(' ', '-').lower()
        ort_link = ort_.lower()
        link = f'https://www.xing.com/jobs/search?keywords=Data%20Engineer&location=Rietberg&page={page_number}&radius={radius}&sort=date'

        driver.get(link)
        wait(5)
        sleep(1)

        #  3 - ActionChain Object created
        # 3.1 - Click Banned Accept
        if page_number == 2:
            ID = 'consent-accept-button'
            click_bann_byID(ID)
        else:
            print(f'Page Numebr = {page_number}')

        # 4 -  Take Infos from Page
        # 4.1 - Headers, Publish_Time ,Company, City
        H = 'utils-line-clamp-lineClamp2-dfe26aab'
        D = 'list-item-job-teaser-list-item-highlight-bb8ddbb6'
        L = 'list-item-job-teaser-list-item-location-a5b28738'
        ALL = 'list-item-job-teaser-list-item-listItem-f04c772e'


        list_header = find_element(H)
        list_description = find_element(D)
        list_ort = find_element(L)
        list_all = find_element(ALL)

        list_publish = []
        list_full_time = [] 
        for i in list_all:
            date = i.split('\n')[-2]
            time_ = i.split('\n')[-3]
            list_publish.append(date)
            list_full_time.append(time_)

        list_title =[]
        list_company = []
        n = 0
        while n < len(list_header):
            list_title.append(list_header[n])
            list_company.append(list_header[n+1])
            n += 2

        # 4.3 - Get Links
        Link = 'list-item-job-teaser-list-item-listItem-f04c772e'
        header = driver.find_elements(By.CLASS_NAME, Link)
        list_link = [link.get_attribute('href') for link in header]

        # 4.4 - DataFrame df
        d = dict(job_title=np.array(list_title), publish=np.array(list_publish), company=np.array(list_company), city=np.array(list_ort) , description=np.array(list_description), link=np.array(list_link))
        df02 = pd.DataFrame.from_dict(d, orient='index')
        df02 = df02.T
        df02['website'] = website_name
        time_now = datetime.today().strftime('%Y-%m-%d %H:%M:%S')
        df02['date'] = time_now
        df02['search_title'] = job_name

        list_of_list = [list_header, list_description, list_ort, list_publish, list_link]
        print([len(i) for i in list_of_list])

        df02.to_csv(f'{path}/{job_name}_first.csv', mode='a', header=False)

# Quit
end =datetime.now() 
print('Code Runned No Problem')
log('end_Xing')
print(f'Time = {end - start}')
sleep(0.5)
driver.quit()

df02.head(2)
# Out:
# ---------------------- Xing Job Searching Selenium Project ----------------------
# [40, 20, 20, 20, 20]
# Page Numebr = 3
# [40, 20, 20, 20, 20]
# Page Numebr = 4
# [40, 20, 20, 20, 20]
# Page Numebr = 5
# [40, 20, 20, 20, 20]
# Page Numebr = 6
# [40, 20, 20, 20, 20]
# Code Runned No Problem
# Time = 0:00:53.874477
#                                    job_title       publish       company  \
# 0             Data Engineer DWH / BI (m/w/d)  Vor 25 Tagen    FALKE KGaA
# 1  Teamlead Data Engineer (m/w/d) | Dortmund  Vor 26 Tagen  ADVERGY GmbH
#
#             city                                        description  \
# 0  Schmallenberg  Verstärken Sie das Team unseres Hauptsitzes am...
# 1       Dortmund  Aufgaben Leitung eines wachsenden Data Enginee...
#
#                                                 link website  \
# 0  https://www.xing.com/jobs/schmallenberg-data-e...    xing
# 1  https://www.xing.com/jobs/dortmund-teamlead-da...    xing
#
#                   date   search_title
# 0  2023-03-14 20:48:07  Data Engineer
# 1  2023-03-14 20:48:07  Data Engineer

# %%
df = pd.read_excel("Data Engineer_first.xlsx", index_col=[0])
df.head()
# Out:
#                                            job_title         publish  \
# 0              Production Quality Supervisor (m/w/d)  vor 15 Stunden
# 1  Sachbearbeiter/in Intel-Officer-Sentinel (w/m/...  vor 18 Stunden
# 2  Data Scientist (m/w/d) Application / (Data Ana...       vor 1 Tag
# 3  Data Scientist (m/w/d) Application / Support (...       vor 1 Tag
# 4                  Process- & Data Architect (d/m/w)       vor 1 Tag
#
#                              company                  city  \
# 0     Polizeipräsidium Gelsenkirchen                Bochum
# 1  Beckhoff Automation GmbH & Co. KG         Gelsenkirchen
# 2  Beckhoff Automation GmbH & Co. KG                  Verl
# 3                    Manufactum GmbH                  Verl
# 4                     Ratbacher GmbH  Waltrop bei Dortmund
#
#                                          description  \
# 0  Molex CVS Bochum GmbH * Bochum * Feste Anstell...
# 1  eine abgeschlossene einschlägige Hochschulausb...
# 2  Kunden- und Applikationssupport für eine Auswa...
# 3  erfolgreich abgeschlossenes Studium der Fachri...
# 4  Für unsere Zentrale in Waltrop (bei Dortmund) ...
#
#                                                 link    website  \
# 0  https://www.stepstone.de/stellenangebote--Prod...  stepstone
# 1  https://www.stepstone.de/stellenangebote--Sach...  stepstone
# 2  https://www.stepstone.de/stellenangebote--Data...  stepstone
# 3  https://www.stepstone.de/stellenangebote--Data...  stepstone
# 4  https://www.stepstone.de/stellenangebote--Proc...  stepstone
#
#                  date   search_title
# 0 2023-03-14 20:29:42  Data Engineer
# 1 2023-03-14 20:29:42  Data Engineer
# 2 2023-03-14 20:29:42  Data Engineer
# 3 2023-03-14 20:29:42  Data Engineer
# 4 2023-03-14 20:29:42  Data Engineer

# %%
print('--------------------------------------- Connect to Database ---------------------------------------')

conn = psycopg2.connect(database="JOB",
			user='postgres', password=1984,
			host='127.0.0.1', port='5432'
)

conn.autocommit = True
cursor = conn.cursor()

log('connected_database')

sql = '''CREATE TABLE IF NOT EXISTS alldata(id serial PRIMARY KEY,
job_title text ,\
publish varchar(30),\
company text,\
city varchar(300),\
description text,\
link text,\
website varchar(30),\
date timestamp,\
search_title varchar(30));'''

cursor.execute(sql)

# connection string: driver://username:password@server/database
engine = create_engine('postgresql+psycopg2://postgres:1984@localhost/JOB')

#  Note:  if_exists can be append, replace, fail.  
df.to_sql('alldata', engine, if_exists='append', index = False)


sql2 = '''SELECT company FROM alldata WHERE publish LIKE '%Stunde%' ORDER BY publish LIMIT 5  '''
cursor.execute(sql2)
for i in cursor.fetchall():
	print(i)

conn.commit()
log('finish_all') 
conn.close()
# Out:
# --------------------------------------- Connect to Database ---------------------------------------
# ('DATAGROUP',)
# ('FROMMER LEGAL',)
# ('Polizeipräsidium Gelsenkirchen',)
# ('DATAGROUP',)
# ('Beckhoff Automation GmbH & Co. KG',)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 225 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     218 non-null    object
#  1   publish       225 non-null    object
#  2   company       221 non-null    object
#  3   city          225 non-null    object
#  4   description   217 non-null    object
#  5   link          225 non-null    object
#  6   website       225 non-null    object
#  7   date          225 non-null    datetime64[ns]
#  8   search_title  225 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 17.6+ KB

# %%
df.search_title.value_counts()
# Out:
# Data Engineer    225
# Name: search_title, dtype: int64

# %%
df.website.value_counts()
# Out:
# stepstone    125
# xing         100
# Name: website, dtype: int64

# %%
df.head(50).link.value_counts()
# Out:
# https://www.stepstone.de/stellenangebote--Production-Quality-Supervisor-m-w-d-Bochum-Molex-CVS-Bochum-GmbH--9329451-inline.html                                                                                                                1
# https://www.stepstone.de/stellenangebote--Absolvent-Career-Starter-als-Software-Developer-m-w-d-Berlin-Bremen-Duesseldorf-Frankfurt-Guetersloh-Hamburg-Karlsruhe-Koeln-Leipzig-und-weitere-Reply--9287869-inline.html                          1
# https://www.stepstone.de/stellenangebote--System-Engineer-Microsoft-Teams-m-w-d-Karlsruhe-Muenster-Atruvia-AG--9179364-inline.html                                                                                                             1
# https://www.stepstone.de/stellenangebote--Senior-IT-Cloud-Architekt-Banking-m-w-d-Berlin-Frankfurt-a-M-Karlsruhe-Koeln-Muenchen-Muenster-Nuernberg-Passau-Stuttgart-msg-systems-ag--8998163-inline.html                                        1
# https://www.stepstone.de/stellenangebote--Testingenieur-m-w-d-Systemtest-Leistungselektronik-Lippstadt-HELLA-Gruppe--9307009-inline.html                                                                                                       1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-w-m-d-Nuernberg-Fuerth-Berlin-Bochum-Chemnitz-Hannover-Luebeck-Mainz-IT-Systemhaus-der-Bundesagentur-fuer-Arbeit--9302256-inline.html                                                1
# https://www.stepstone.de/stellenangebote--DevOps-Engineers-w-m-d-im-Umfeld-SharePoint-Nuernberg-Fuerth-Berlin-Bochum-Chemnitz-Hannover-Luebeck-Mainz-IT-Systemhaus-der-Bundesagentur-fuer-Arbeit--9302229-inline.html                          1
# https://www.stepstone.de/stellenangebote--Data-Scientist-m-w-d-Dortmund-Dortmunder-Energie-und-Wasserversorgung-GmbH--9246416-inline.html                                                                                                      1
# https://www.stepstone.de/stellenangebote--Network-Security-Engineer-Experte-m-w-d-IT-Sicherheit-und-Netzwerke-Osnabrueck-OSMA-Aufzuege-Albert-Schenk-GmbH-Co-KG--9303243-inline.html                                                           1
# https://www.stepstone.de/stellenangebote--Computational-Biologist-Data-Scientist-m-f-d-Einbeck-KWS-Group--9244632-inline.html                                                                                                                  1
# https://www.stepstone.de/stellenangebote--DevOps-m-w-d-Engineer-Duisburg-Hannover-Wedemark-Muenster-Ratiodata-SE--8855887-inline.html                                                                                                          1
# https://www.stepstone.de/stellenangebote--Software-Developer-m-w-d-fuer-Forschungsprojekte-Paderborn-dSPACE-GmbH--9295890-inline.html                                                                                                          1
# https://www.stepstone.de/stellenangebote--Business-Intelligence-Analyst-w-m-d-Muenster-Viehoff-Gruppe--9244540-inline.html                                                                                                                     1
# https://www.stepstone.de/stellenangebote--Sachbearbeiter-in-Intel-Officer-Sentinel-w-m-d-Data-Scientist-Gelsenkirchen-Marketplace-Hub--9328607-inline.html                                                                                     1
# https://www.stepstone.de/stellenangebote--Cyber-Defense-Engineer-Privileged-Session-Management-m-w-d-Karlsruhe-Muenchen-Muenster-Atruvia-AG--9033887-inline.html                                                                               1
# https://www.stepstone.de/stellenangebote--Advanced-Systems-Engineer-m-w-d-Lippstadt-HELLA-Gruppe--9295260-inline.html                                                                                                                          1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-Development-and-Operations-Engineer-w-d-m-Oldenburg-Osnabrueck-und-Braunschweig-EWE-TEL-GmbH--9295221-inline.html                                                                    1
# https://www.stepstone.de/stellenangebote--Software-Engineer-Meldewesen-m-w-d-Karlsruhe-Muenster-Atruvia-AG--9272336-inline.html                                                                                                                1
# https://www.stepstone.de/stellenangebote--System-Engineer-m-w-d-Schwerpunkt-IT-Netzwerktechnologien-Kassel-Controlware-GmbH--9298983-inline.html                                                                                               1
# https://www.stepstone.de/stellenangebote--Netzwerkadministrator-m-w-d-Network-Engineer-Bielefeld-Ratbacher-GmbH--9293303-inline.html                                                                                                           1
# https://www.stepstone.de/stellenangebote--Platform-Engineer-Datenbanken-m-w-d-Osnabrueck-Braunschweig-ITEBO-GmbH--9293608-inline.html                                                                                                          1
# https://www.stepstone.de/stellenangebote--Supplier-Quality-Engineer-m-w-d-Bochum-Molex-CVS-Bochum-GmbH--9294569-inline.html                                                                                                                    1
# https://www.stepstone.de/stellenangebote--Enterprise-Data-Architect-m-f-d-Berlin-Verl-Baden-Baden-Riverty--9239397-inline.html                                                                                                                 1
# https://www.stepstone.de/stellenangebote--Cloud-System-Engineer-m-w-d-Berlin-Hamburg-Muenchen-Koeln-Frankfurt-a-M-Stuttgart-Dresden-Dortmund-Kempten-Karlsruhe-DACHSER-SE--9118203-inline.html                                                 1
# https://www.stepstone.de/stellenangebote--Development-Operations-DevOps-m-w-d-System-Engineering-Osnabrueck-HagerEnergy-GmbH--9251429-inline.html                                                                                              1
# https://www.stepstone.de/stellenangebote--Support-Engineer-Operations-Command-Center-SOC-m-w-d-Bielefeld-OEDIV-Oetker-Daten-und-Informationsverarbeitung-KG--9256794-inline.html                                                               1
# https://www.stepstone.de/stellenangebote--Engineering-Manager-m-w-d-Validation-Project-Management-Bochum-Molex-CVS-Bochum-GmbH--9254785-inline.html                                                                                            1
# https://www.stepstone.de/stellenangebote--Junior-Client-Engineer-m-w-d-Duisburg-Hannover-Muenster-Koblenz-Ratiodata-SE--7504371-inline.html                                                                                                    1
# https://www.stepstone.de/stellenangebote--Data-Scientist-m-w-d-Application-Data-Analytics-Condition-Monitoring-Verl-Beckhoff-Automation-GmbH-Co-KG--9325862-inline.html                                                                        1
# https://www.stepstone.de/stellenangebote--Data-Scientist-m-w-d-Application-Support-Simulation-Machine-Learning-Verl-Beckhoff-Automation-GmbH-Co-KG--9325861-inline.html                                                                        1
# https://www.stepstone.de/stellenangebote--Process-Data-Architect-d-m-w-Waltrop-bei-Dortmund-Manufactum-GmbH--8744496-inline.html                                                                                                               1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-m-w-d-DevOps-Spezialist-Bielefeld-Stuttgart-Dresden-oder-Regensburg-Ratbacher-GmbH--9324212-inline.html                                                                              1
# https://www.stepstone.de/stellenangebote--Senior-Enterprise-Architekt-m-w-d-Dortmund-Hamburg-SIGNAL-IDUNA-Gruppe--9257441-inline.html                                                                                                          1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-m-w-d-Luenen-REMONDIS-IT-Services-GmbH-Co-KG--9266198-inline.html                                                                                                                    1
# https://www.stepstone.de/stellenangebote--Software-Developer-DevOps-m-w-d-Anwendungsentwicklung-und-Deployment-Muenster-EVIDENT-Technology-Center-Europe-GmbH--9265936-inline.html                                                             1
# https://www.stepstone.de/stellenangebote--PowerPlatform-Engineer-m-w-d-Bielefeld-Leipzig-Plauen-GOLDBECK-GmbH--9262545-inline.html                                                                                                             1
# https://www.stepstone.de/stellenangebote--Open-Source-Software-Analyst-m-w-d-Bochum-Volkswagen-Infotainment-GmbH--9032645-inline.html                                                                                                          1
# https://www.stepstone.de/stellenangebote--Softwareanalyst-ERP-m-w-d-Luenen-REMONDIS-IT-Services-GmbH-Co-KG--9266208-inline.html                                                                                                                1
# https://www.stepstone.de/stellenangebote--Senior-Bauingenieur-Architekt-m-w-d-Bauen-im-Bestand-Dortmund-Frankfurt-am-Main-Hamburg-Muenchen-Leipzig-Mannheim-Nuernberg-ISS-Facility-Services-Holding-GmbH--9265426-inline.html                  1
# https://www.stepstone.de/stellenangebote--Digital-Analyst-m-w-d-Minden-WAGO-GmbH-Co-KG--9262215-inline.html                                                                                                                                    1
# https://www.stepstone.de/stellenangebote--Technical-Consultant-m-w-d-Software-Implementierung-ECM-DMS-Dortmund-OPTIMAL-SYSTEMS-GmbH--8337646-inline.html                                                                                       1
# https://www.stepstone.de/stellenangebote--Software-Developer-m-w-d-Ennepetal-Ferdinand-Bilstein-GmbH-Co-KG--9260363-inline.html                                                                                                                1
# https://www.stepstone.de/stellenangebote--DevOps-Cloud-Engineer-m-w-d-Bremen-Bielefeld-Muenster-Oldenburg-Hamburg-Hannover-Osnabrueck-Essen-Dortmund-Lingen-Meppen-SYMBIONET-AG--9258021-inline.html                                           1
# https://www.stepstone.de/stellenangebote--Data-Scientist-m-w-d-Bundesweit-Duesseldorf-Dortmund-Koeln-Frankfurt-am-Main-Hamburg-Stuttgart-ORAYLIS-GmbH--7236845-inline.html                                                                     1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-m-w-d-Paderborn-dSPACE-GmbH--9200847-inline.html                                                                                                                                     1
# https://www.stepstone.de/stellenangebote--Web-Analyst-m-w-d-Bochum-Ausbildung-de--9317568-inline.html                                                                                                                                          1
# https://www.stepstone.de/stellenangebote--Salesforce-Engineer-m-w-d-Bochum-Ausbildung-de--9317554-inline.html                                                                                                                                  1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-VMware-m-w-d-Home-Office-bundesweit-Bielefeld-Dresden-Hamburg-Koeln-PlusServer-GmbH--9318890-inline.html                                                                             1
# https://www.stepstone.de/stellenangebote--Support-Engineer-IT-Servicedesk-2nd-Level-Support-Junior-m-w-d-Bielefeld-Rostock-Oldenburg-Berlin-Frankfurt-am-Main-Koeln-OEDIV-Oetker-Daten-und-Informationsverarbeitung-KG--9257175-inline.html    1
# https://www.stepstone.de/stellenangebote--DevOps-Engineer-m-w-d-Muenster-Vectron-Systems-AG--8859744-inline.html                                                                                                                               1
# Name: link, dtype: int64
