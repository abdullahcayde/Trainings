# %%
import ipytest
ipytest.autoconfig()

import pytest

import pandas as pd
import numpy as np
from numpy import nan

import datetime as dt

import warnings
warnings.simplefilter(action='ignore')

# %%
path = '/Users/macbook/Desktop/IBM/KPMG_intership/01 _Data_Quality_Assessment/KPMG.xlsx'
df1 = pd.read_excel(path, sheet_name='CustomerDemographic', skiprows= 1)
df2 = pd.read_excel(path, sheet_name='CustomerAddress', skiprows= 1)
df3 = pd.read_excel(path, sheet_name='Transactions', skiprows= 1)
df4 = pd.read_excel(path, sheet_name='NewCustomerList', skiprows= 1)

# %% [markdown]
# # All Functions Pytest

# %%
# %%ipytest
#
# # check if column exists
# def test_col_exists(df):
#     name="column01"
#     assert name in df.columns
#
# # check for nulls
# def test_null_check(df):
#     assert df['column01'].notnull().all()
#
# # check values are unique
# def test_unique_check(df):
#     assert pd.Series(df['column01']).is_unique
#
# # check data type
# def test_productkey_dtype_int(df):
#     assert (df['column01'].dtype == int or df['column01'].dtype == np.int64)
#
# # check data type
# def test_productname_dtype_srt(df):
#     assert (df['EnglishProductName'].dtype == str or  df['EnglishProductName'].dtype == 'O')
#
# # check values in range
# def test_range_val(df):
#     assert df['SafetyStockLevel'].between(0,1000).any()
#
# # check values in a list
# def test_range_val_str(df):
#     assert set(df.Color.unique()) == {'NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow','Grey', 'Silver/Black'}
# Out:
# ...                                                                                          [100%]
# 3 passed in 0.02s

# %% [markdown]
# # Address Data Pytest Functions

# %%
df2.head(2)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
#
#    property_valuation
# 0                  10
# 1                  10

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
df2.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
# %%ipytest
#
# # 01 - check values are unique
# def test_unique_check():
#     assert pd.Series(df2['customer_id']).is_unique
#
# # 02 - check null
# def test_null_check():
#     for col in df2.columns:
#         assert df2[col].notnull().all()
#
# # 03 - check data type numeric
# def test_dtype_int():
#     numeric = df2.select_dtypes(include=np.number)
#     for col in numeric:
#         assert (df2[col].dtype == int or df2[col].dtype == np.int64)
#
# # 04 - check data type categoric
# def test_dtype_categoric():
#     categoric = df2.select_dtypes(exclude=np.number)
#     for col in categoric:
#         assert (df2[col].dtype == str or df2[col].dtype == object)
# Out:
# ....                                                                                         [100%]
# 4 passed in 0.17s

# %%
df2[df2.address.str.startswith(('0 ', '00 ', '000 '))]
# Out:
#       customer_id                 address  postcode            state  \
# 2               4      0 Holy Cross Court      4211              QLD
# 107           112         0 David Terrace      3204              VIC
# 122           127      0 Pearson Crossing      4405              QLD
# 133           138  0 Golden Leaf Crossing      2033  New South Wales
# 152           157       0 Hazelcrest Road      3025              VIC
# ...           ...                     ...       ...              ...
# 3723         3728    0 Declaration Center      2250              NSW
# 3859         3864        0 Arapahoe Court      4305              QLD
# 3904         3909       0 Darwin Junction      2747              NSW
# 3917         3922      0 Southridge Drive      4311              QLD
# 3991         3996      0 Transport Center      3977              VIC
#
#         country  property_valuation
# 2     Australia                   9
# 107   Australia                  11
# ...

# %% [markdown]
# # CustomerDemographics Data Pytest Functions

# %%
df1.head(2)
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            2        Eli    Bockman   Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator  \
# 0                Health  Mass Customer                  N
# 1    Financial Services  Mass Customer                  N
#
#                         default owns_car  tenure
# 0                            "'      Yes    11.0
# 1  <script>alert('hi')</script>      Yes    16.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
# %%ipytest
#
#
# # 01 - check values are unique
# def test_unique_check():
#     assert pd.Series(df1['customer_id']).is_unique
#
# # 02 - check null
# #def test_null_check():
# #    for col in df1.columns:
# #        assert df1[col].notnull().all()
#
# # 03 - check data type numeric
# def test_dtype_int():
#     numeric = df1.select_dtypes(include=np.number)
#     for col in numeric:
#         assert (df1[col].dtype == int or df1[col].dtype == np.int64 or df1[col].dtype == np.float64)
#
# # 04 - check data type categoric
# def test_dtype_categoric():
#     categoric = df1.select_dtypes(exclude=np.number)
#     for col in categoric:
#         assert (df1[col].dtype == str or df1[col].dtype == object or df1[col].dtype == '<M8[ns]')
#
# # check values in range
# def test_range_val_date_column():
#     assert df1.DOB.dropna().dt.day.between(1, 31).all()
#     assert df1.DOB.dropna().dt.month.between(1, 12).all()
#     assert df1.DOB.dropna().dt.year.between(1917, 2002).all()
#
# #
# def test_range_val_past3_column():
#     assert df1.past_3_years_bike_related_purchases.dropna().between(1,9999).all()
#
# # check values in a list
# def test_range_val_str():
#     assert set(df1.gender.unique()) == {'Male', 'Female'}
# Out:
# ...FFF                                                                                       [100%]
# ============================================= FAILURES =============================================
# ____________________________________ test_range_val_date_column ____________________________________
#
#     def test_range_val_date_column():
#         assert df1.DOB.dropna().dt.day.between(1, 31).all()
#         assert df1.DOB.dropna().dt.month.between(1, 12).all()
# >       assert df1.DOB.dropna().dt.year.between(1917, 2002).all()
# E       assert False
# E        +  where False = <bound method NDFrame._add_numeric_operations.<locals>.all of 0       True\n1       True\n2       True\n3       True\n4   ...rue\n        ... \n3994    True\n3995    True\n3996    True\n3998    True\n3999    True\nName: DOB, Length: 3913, dtype: bool>()
# ...

# %%
df1.isna().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
for i in df1.columns:
    print(i, df1[i].unique(), '\n')
# Out:
# customer_id [   1    2    3 ... 3998 3999 4000]
#
# first_name ['Laraine' 'Eli' 'Arlin' ... 'Stephie' 'Rusty' 'Sarene']
#
# last_name ['Medendorp' 'Bockman' 'Dearle' ... 'Halgarth' 'Woolley' 'Oldland']
#
# gender ['F' 'Male' 'Female' 'U' 'Femal' 'M']
#
# past_3_years_bike_related_purchases [93 81 61 33 56 35  6 31 97 49 99 58 38 85 91 57 79 76 72 74 43 55 12 37
#   5 62 18  3 17 44 59 40 46 64 24 63 98 51 68 22  2 48 87 26 60 47 73 21
#  67 16 78 30 94 28 20 11  1 75 41 69 19 80 83 25 54  4 23 65 88 10 77  9
#  82 27 53 32 34 71 36 90 95  8 39  7 42 13 45 50 14 89 84 96 70 66  0 15
#  86 92 29 52]
#
# DOB ['1953-10-12T00:00:00.000000000' '1980-12-16T00:00:00.000000000'
#  '1954-01-20T00:00:00.000000000' ... '1975-12-12T00:00:00.000000000'
#  '2001-07-13T00:00:00.000000000' '1991-11-05T00:00:00.000000000']
#
# job_title ['Executive Secretary' 'Administrative Officer' 'Recruiting Manager' nan
#  'Senior Editor' 'Media Manager I' 'Business Systems Development Analyst'
# ...

# %%
df1.query('past_3_years_bike_related_purchases == 0')
# Out:
#       customer_id  first_name    last_name  gender  \
# 278           279      Tamera      Hinckes  Female
# 309           310     Myranda      Clowser  Female
# 427           428      Freida       Everil  Female
# 459           460        Illa          NaN  Female
# 474           475      Vernor          NaN    Male
# 485           486       Prudi         Edon  Female
# 571           572  Clementius   Everington    Male
# 601           602      Lebbie        Bruck  Female
# 928           929       Kippy    Conerding    Male
# 980           981         Bud    Smittoune    Male
# 1015         1016      Adrian  Prettyjohns    Male
# 1041         1042      Isacco     Woodwind    Male
# 1045         1046        Shir      Clevely  Female
# 1194         1195        Ally     Folliott  Female
# 1213         1214     Martino     Shalcros    Male
# 1290         1291      Warner        Zuker    Male
# 1299         1300      Sisely   Strelitzer  Female
# ...

# %%
df1.DOB.dropna().dt.year.between(1917, 2002).all()
# Out:
# False

# %%
df1.DOB.dt.month.describe()
# Out:
# count    3913.000000
# mean        6.522872
# std         3.462707
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        10.000000
# max        12.000000
# Name: DOB, dtype: float64

# %%
df1.DOB.dropna().dt.year >= 1917
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3994    True
# 3995    True
# 3996    True
# 3998    True
# 3999    True
# Name: DOB, Length: 3913, dtype: bool

# %% [markdown]
# # Summarize all datas

# %% [markdown]
# Sheet name : CustomerAddress
# - column address : 99 rows started with 0, 00 or 000 and doesn't have any number more.
# - column state : some of them have only capital letter , some of them all the name
#     New South Wales, NSW, QLD, VIC, Victoria
# - the other seems normal
#
#
# Sheet name

# %%
df1.head(1)
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   93 1953-10-12  Executive Secretary
#
#   job_industry_category wealth_segment deceased_indicator default owns_car  \
# 0                Health  Mass Customer                  N      "'      Yes
#
#    tenure
# 0    11.0

# %%
df2.head(1)
# Out:
#    customer_id             address  postcode            state    country  \
# 0            1  060 Morning Avenue      2016  New South Wales  Australia
#
#    property_valuation
# 0                  10

# %%
df3.head(1)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
#
#   order_status  brand product_line product_class product_size  list_price  \
# 0     Approved  Solex     Standard        medium       medium       71.49
#
#    standard_cost  product_first_sold_date
# 0          53.62                  41245.0

# %%
df3.customer_id.sort_values().unique()
# Out:
# array([   1,    2,    3, ..., 3499, 3500, 5034])

# %%
df1.customer_id.sort_values().unique()
# Out:
# array([   1,    2,    3, ..., 3998, 3999, 4000])
