# %%
import numpy as np
import pandas as pd
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore')

# %%
tips = sns.load_dataset('tips')
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # <font color=red>Kolon islemleri<font>

# %% [markdown]
# ### Kolonu index olarak atamak

# %%
df = df.set_index(['kolon_adi'])

# %% [markdown]
# ### replace (istenmiyen isimleri silmek)

# %%
#define DataFrame
df = pd.DataFrame({'$team':['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
                   '$points': [25, 12, 15, 14, 19, 23, 25, 29],
                   '$assists': [5, 7, 7, 9, 12, 9, 9, 4],
                   '$rebounds': [11, 8, 10, 6, 6, 5, 9, 12]})
df.head()
# Out:
#   $team  $points  $assists  $rebounds
# 0     A       25         5         11
# 1     A       12         7          8
# 2     A       15         7         10
# 3     A       14         9          6
# 4     B       19        12          6

# %%
df.columns = df.columns.str.replace('$', '')
df.head(2)
# Out:
#   team  points  assists  rebounds
# 0    A      25        5        11
# 1    A      12        7         8

# %% [markdown]
# ### Butun Kolonlari ve Satir Gostermek

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Butun Kolonlari ve Satir Gostermek 2

# %%
# set colwidth hidher
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ### Reset Butun Kolon Gorme

# %%
pd.reset_option('max_columns')
pd.reset_option('max_rows')

# %%
pd.reset_option('max_columns')
pd.set_option('display.max_rows', 10)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Butun Kolon Gosterme Kontrol Etmek

# %%
len(df.columns)

pd.get_option('display.max_columns')
# Out:
# 20

# %% [markdown]
# ### Kolona Eleman Ekleme islemi

# %%
df = df.append({'total_bill': 1500}, ignore_index= True)
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0
# 244     1500.00   NaN     NaN    NaN   NaN     NaN   NaN

# %%
# Append

Signature:
df.append(
    other,
    ignore_index: 'bool' = False,
    verify_integrity: 'bool' = False,
    sort: 'bool' = False,
) -> 'DataFrame'
Docstring:
Append rows of `other` to the end of caller, returning a new object.

Columns in `other` that are not in the caller are added as new columns.

Parameters
----------
other : DataFrame or Series/dict-like object, or list of these
    The data to append.
ignore_index : bool, default False
    If True, the resulting axis will be labeled 0, 1, …, n - 1.
verify_integrity : bool, default False
    If True, raise ValueError on creating index with duplicates.
sort : bool, default False
    Sort columns if the columns of `self` and `other` are not aligned.

# %% [markdown]
# # <font color=red>Secim islemleri<font>

# %% [markdown]
# ### Random index secmek

# %%
df.sample()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 3       23.68  3.31  Male     No  Sun  Dinner     2

# %%
df.sample(n=7)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 175       32.90   3.11    Male    Yes   Sun  Dinner     2
# 41        17.46   2.54    Male     No   Sun  Dinner     2
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 145        8.35   1.50  Female     No  Thur   Lunch     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 178        9.60   4.00  Female    Yes   Sun  Dinner     2
# 57        26.41   1.50  Female     No   Sat  Dinner     2

# %%
# ?df.sample

Signature:
df.sample(
    n=None,   ======> (eleman sayisi)
    frac: 'float | None' = None, ======> (yuzdelik oran .5 yuzde ellisi)
    replace: 'bool_t' = False,   ======> (tekrar eden index olsun mu)
    weights=None,
    random_state=None,           ======> (sayi gir , seed gibi , hep ayni ornek gelir)
    axis: 'Axis | None' = None,  ======> (1 olursa rastgele kolon secer)
    ignore_index: 'bool_t' = False,

# %%
# Istenilen Tipte degisken Secimi (select_dtypes())

# %%
df1 = df.select_dtypes(include= ['float64', 'int64'])
df1.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %% [markdown]
# ## assign()

# %%
df = pd.DataFrame({'c1': list('abcdefg')})
df.loc[5, 'c1'] = 'Value'
df
# Out:
#       c1
# 0      a
# 1      b
# 2      c
# 3      d
# 4      e
# 5  Value
# 6      g

# %%
df = df.assign(c2 = df.c1)
# OR:
#df['c2'] = df['c1']
df
# Out:
#       c1     c2
# 0      a      a
# 1      b      b
# 2      c      c
# 3      d      d
# 4      e      e
# 5  Value  Value
# 6      g      g

# %%
df.loc[df['c1'] == 'Value', 'c2'] = 10
df
# Out:
#       c1  c2
# 0      a   a
# 1      b   b
# 2      c   c
# 3      d   d
# 4      e   e
# 5  Value  10
# 6      g   g

# %%
# ?df.assign
# Out:
# Signature: df.assign(**kwargs) -> 'DataFrame'
# Docstring:
# Assign new columns to a DataFrame.
#
# Returns a new object with all original columns in addition to new ones.
# Existing columns that are re-assigned will be overwritten.
#
# Parameters
# ----------
# **kwargs : dict of {str: callable or Series}
#     The column names are keywords. If the values are
#     callable, they are computed on the DataFrame and
#     assigned to the new columns. The callable must not
#     change input DataFrame (though pandas doesn't check it).
#     If the values are not callable, (e.g. a Series, scalar, or array),
#     they are simply assigned.
#
# Returns
# -------
# DataFrame
#     A new DataFrame with the new columns in addition to
#     all the existing columns.
#
# Notes
# -----
# Assigning multiple columns within the same ``assign`` is possible.
# Later items in '\*\*kwargs' may refer to newly created or modified
# columns in 'df'; items are computed and assigned into 'df' in order.
#
# ...
