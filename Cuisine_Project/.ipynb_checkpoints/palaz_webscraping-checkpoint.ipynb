# %%
import time
from datetime import datetime

from selenium import webdriver
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

import warnings
warnings.simplefilter(action='ignore')

# %%
# Sleep function 
def sleep(x):
    time.sleep(x)

# Wait for a certain measure of time before throwing an exception
def wait(x):
    driver.implicitly_wait(x)

    
# Find Elements Function
def find_elements_TAPF(T,A,P,F):

    titles = driver.find_elements(By.CLASS_NAME, T)
    address = driver.find_elements(By.CLASS_NAME, A)
    prices = driver.find_elements(By.CLASS_NAME, P)
    features = driver.find_elements(By.CLASS_NAME, F) 

    list_title = [title.text for title in titles]
    list_address = [addr.text for addr in address]
    list_price = [price.text for price in prices]
    list_features = [feature.text for feature in features]
    return list_title, list_address, list_price, list_features

# %%
print('---------------------- Selenium House-Rotterdam Web-Scraping Project ----------------------')
start=datetime.now()

#  1 - Create Driver
Path = '/Users/macbook/Desktop/projects/Github_Repositories/Portfolio Projects/02 - Web_Scraping_Job_Search/chromedriver'
driver = webdriver.Chrome(Path)

#  2 - Go to Website
link = 'https://www.pararius.com/apartments/rotterdam?ac=1'

driver.get(link)
wait(10)
sleep(2)

# 3 - number of results
total_house_number = driver.find_elements(By.CLASS_NAME, 'search-list-header__count')
list_result = [tt.text for tt in total_house_number]
print(f' Total Number of house = {int(list_result[0])}\n' )


# Number of Page
#num_of_page = driver.find_elements(By.CLASS_NAME, '')

# 4 -  Take Infos from Page
# 4.1 - Headers, Publish_Time ,Company, City
T, A, P, F = 'listing-search-item__title', "listing-search-item__sub-title\\'", 'listing-search-item__price', 'listing-search-item__features'
list_title, list_address, list_price, list_features = find_elements_TAPF(T,A,P,F)

print(f'{list_title[1]} , {list_address[1]} , {list_price[1]} , {list_features[1]}\n')

all_list = [list_title, list_address, list_price, list_features]

for i in all_list:
    print(len(i))

    
# 4.6 - DataFrame df
d = dict(title=np.array(list_title), address=np.array(list_address), price=np.array(list_price),
         duzenle=np.array(list_features) )
df = pd.DataFrame.from_dict(d, orient='index')
df = df.T
    
# Page number deneme
page_nums = driver.find_elements(By.CLASS_NAME, 'pagination')
list_page = [i.text for i in page_nums]
a = str(list_page)
page_number = int(a[-10:-8])
print('Total Page number = ', page_number)

num = 1
while num < page_number:
    try:
        num+=1

        # 4.7.1 - Go to another page
        'https://www.pararius.com/apartments/rotterdam/page-2'
        link = f'https://www.pararius.com/apartments/rotterdam/page-{num}'
        driver.get(link)
        wait(10)
        sleep(1.5)

        # Take infos from page
        list_title, list_address, list_price, list_features = find_elements_TAPF(T,A,P,F)

        # Data Frame
        d = dict(title=np.array(list_title), address=np.array(list_address), price=np.array(list_price),
             duzenle=np.array(list_features) )
        df2 = pd.DataFrame.from_dict(d, orient='index')
        df2 = df2.T
    except:
        pass

    # 4.7.4 - Concatenate the DataFrames
    df = pd.concat([df,df2], axis=0, ignore_index=True)
    print(f'Page Number : {num}, DataFrame Shape : {df2.shape}')
    

# Data Cleaning
df.duzenle = df.duzenle.str.replace('\n', '/')
df[['m2', 'rooms', 'furnished']] = df.duzenle.str.split('/', expand=True)
    
# 5.1 - Save Data as csv 
print(f'DataFrame End : {df.shape}')
df.to_csv('rotterdam.csv', index=False)


# 6 - Quit
end =datetime.now() 
print('Code Runned, No Problem')
print(f'Time = {end - start}')
sleep(5)
driver.quit()

df.head()
# Out:
# ---------------------- Selenium House-Rotterdam Web-Scraping Project ----------------------
#  Total Number of house = 617
#
# Apartment Oostmaaslaan , 3063 AN Rotterdam (Struisenburg) , €1,450 per month , 65 m²
# 3 rooms
# Furnished
#
# 32
# 32
# 32
# 32
# Total Page number =  21
# Page Number : 2, DataFrame Shape : (32, 4)
# Page Number : 3, DataFrame Shape : (32, 4)
# Page Number : 4, DataFrame Shape : (32, 4)
# Page Number : 5, DataFrame Shape : (32, 4)
# Page Number : 6, DataFrame Shape : (32, 4)
# Page Number : 7, DataFrame Shape : (32, 4)
# Page Number : 8, DataFrame Shape : (32, 4)
# Page Number : 9, DataFrame Shape : (32, 4)
# Page Number : 10, DataFrame Shape : (32, 4)
# Page Number : 11, DataFrame Shape : (32, 4)
# Page Number : 12, DataFrame Shape : (32, 4)
# Page Number : 13, DataFrame Shape : (32, 4)
# Page Number : 14, DataFrame Shape : (32, 4)
# Page Number : 15, DataFrame Shape : (32, 4)
# Page Number : 16, DataFrame Shape : (32, 4)
# Page Number : 17, DataFrame Shape : (32, 4)
# Page Number : 18, DataFrame Shape : (32, 4)
# Page Number : 19, DataFrame Shape : (32, 4)
# Page Number : 20, DataFrame Shape : (32, 4)
# Page Number : 21, DataFrame Shape : (19, 4)
# DataFrame End : (659, 7)
# Code Runned, No Problem
# Time = 0:02:17.041740
#                             title                             address  \
# 0  House Burgemeester Meineszlaan   3022 BC Rotterdam (Nieuwe Westen)
# 1          Apartment Oostmaaslaan    3063 AN Rotterdam (Struisenburg)
# 2              Apartment Boompjes   3011 XZ Rotterdam (Stadsdriehoek)
# 3         Apartment Hermonlaan 64  3061 BH Rotterdam (Kralingen West)
# 4         Apartment Hermonlaan 35  3061 BH Rotterdam (Kralingen West)
#
#               price                    duzenle     m2    rooms    furnished
# 0  €2,800 per month              82 m²/5 rooms  82 m²  5 rooms         None
# 1  €1,450 per month    65 m²/3 rooms/Furnished  65 m²  3 rooms    Furnished
# 2  €1,625 per month    59 m²/2 rooms/Furnished  59 m²  2 rooms    Furnished
# 3  €2,000 per month    80 m²/3 rooms/Furnished  80 m²  3 rooms    Furnished
# 4  €1,495 per month  75 m²/3 rooms/Upholstered  75 m²  3 rooms  Upholstered

# %%
df.duplicated().sum()
# Out:
# 66

# %%
df[df.duplicated()]
# Out:
#                               title                             address  \
# 33   House Burgemeester Meineszlaan   3022 BC Rotterdam (Nieuwe Westen)
# 64   House Burgemeester Meineszlaan   3022 BC Rotterdam (Nieuwe Westen)
# 65           Apartment Oostmaaslaan    3063 AN Rotterdam (Struisenburg)
# 96         Apartment Stationssingel  3033 HE Rotterdam (Provenierswijk)
# 97           Apartment Oostmaaslaan    3063 AN Rotterdam (Struisenburg)
# ..                              ...                                 ...
# 627            Studio Eendrachtsweg            3012 LG Rotterdam (Cool)
# 629      Studio Witte de Withstraat            3012 BN Rotterdam (Cool)
# 640  House Burgemeester Meineszlaan   3022 BC Rotterdam (Nieuwe Westen)
# 641        Apartment Stationssingel  3033 HE Rotterdam (Provenierswijk)
# 657             Apartment Kruiskade            3012 EG Rotterdam (Cool)
#
#                 price                    duzenle     m2    rooms    furnished
# 33   €2,800 per month              82 m²/5 rooms  82 m²  5 rooms         None
# 64   €2,800 per month              82 m²/5 rooms  82 m²  5 rooms         None
# 65   €1,450 per month    65 m²/3 rooms/Furnished  65 m²  3 rooms    Furnished
# 96   €1,595 per month  99 m²/3 rooms/Upholstered  99 m²  3 rooms  Upholstered
# 97   €1,450 per month    65 m²/3 rooms/Furnished  65 m²  3 rooms    Furnished
# ..                ...                        ...    ...      ...          ...
# 627  €1,650 per month     50 m²/1 room/Furnished  50 m²   1 room    Furnished
# 629  €1,800 per month     40 m²/1 room/Furnished  40 m²   1 room    Furnished
# 640  €2,800 per month              82 m²/5 rooms  82 m²  5 rooms         None
# 641  €1,595 per month  99 m²/3 rooms/Upholstered  99 m²  3 rooms  Upholstered
# 657  €1,350 per month        78 m²/2 rooms/Shell  78 m²  2 rooms        Shell
#
# [66 rows x 7 columns]
