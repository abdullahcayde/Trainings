# %% [markdown]
# # Veriye Ilk Bakis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## <font color='red'>Ozel Ayarlar</font>

# %%
import warnings
warnings.simplefilter(action='ignore')

#Butun kolon ve satirlari gormek icin
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

#virgulden sonra gösterilecek olan sayı 2 basamak olarak ayarlanıyor.
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Grafik Ayarlari
# Arka tarf cizgili olur
sns.set_theme(style="whitegrid")

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1          269.30  7.10     77.40  2006
# 1  Radial Velocity       1          874.77  2.21     56.95  2008
# 2  Radial Velocity       1          763.00  2.60     19.84  2011
# 3  Radial Velocity       1          326.03 19.40    110.62  2007
# 4  Radial Velocity       1          516.22 10.50    119.47  2009

# %% [markdown]
# # 00_ilk Soru =  Veri Setinin Hikayesi nedir ?
#
# ##  Bilesenlerin Olusma Hikayesi nedir ?

# %% [markdown]
# # 01) df = file.copy  (Kopya Almak)

# %%
df = planets.copy()

# %%
df.head()
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1          269.30  7.10     77.40  2006
# 1  Radial Velocity       1          874.77  2.21     56.95  2008
# 2  Radial Velocity       1          763.00  2.60     19.84  2011
# 3  Radial Velocity       1          326.03 19.40    110.62  2007
# 4  Radial Velocity       1          516.22 10.50    119.47  2009

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1            3.94   NaN    172.00  2006
# 1031  Transit       1            2.62   NaN    148.00  2007
# 1032  Transit       1            3.19   NaN    174.00  2007
# 1033  Transit       1            4.13   NaN    293.00  2008
# 1034  Transit       1            4.19   NaN    260.00  2008

# %% [markdown]
# # Veri Seti Yapisal Bilgileri

# %% [markdown]
# # 02) df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %% [markdown]
# # 03) df.dtypes

# %%
df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %% [markdown]
# # 04)  odbject to category degistir

# %%
df.method = pd.Categorical(df.method)
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
type(df.method)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 05) df.describe()  ====> Kategorik Degiskenler sayi ile ifade edilmis mi?

# %%
df.describe().T
# Out:
#                  count    mean      std     min     25%     50%     75%  \
# number         1035.00    1.79     1.24    1.00    1.00    1.00    2.00
# orbital_period  992.00 2002.92 26014.73    0.09    5.44   39.98  526.00
# mass            513.00    2.64     3.82    0.00    0.23    1.26    3.04
# distance        808.00  264.07   733.12    1.35   32.56   55.25  178.50
# year           1035.00 2009.07     3.97 1989.00 2007.00 2010.00 2012.00
#
#                      max
# number              7.00
# orbital_period 730000.00
# mass               25.00
# distance         8500.00
# year             2014.00

# %%
df.describe(include = 'all').T
# Out:
#                  count unique              top freq    mean      std     min  \
# method            1035     10  Radial Velocity  553     NaN      NaN     NaN
# number         1035.00    NaN              NaN  NaN    1.79     1.24    1.00
# orbital_period  992.00    NaN              NaN  NaN 2002.92 26014.73    0.09
# mass            513.00    NaN              NaN  NaN    2.64     3.82    0.00
# distance        808.00    NaN              NaN  NaN  264.07   733.12    1.35
# year           1035.00    NaN              NaN  NaN 2009.07     3.97 1989.00
#
#                    25%     50%     75%       max
# method             NaN     NaN     NaN       NaN
# number            1.00    1.00    2.00      7.00
# orbital_period    5.44   39.98  526.00 730000.00
# mass              0.23    1.26    3.04     25.00
# distance         32.56   55.25  178.50   8500.00
# year           2007.00 2010.00 2012.00   2014.00

# %% [markdown]
# # 06) Eksikdegerlerin incelenmesi

# %%
df.head()
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1          269.30  7.10     77.40  2006
# 1  Radial Velocity       1          874.77  2.21     56.95  2008
# 2  Radial Velocity       1          763.00  2.60     19.84  2011
# 3  Radial Velocity       1          326.03 19.40    110.62  2007
# 4  Radial Velocity       1          516.22 10.50    119.47  2009

# %% [markdown]
# ## <font color='red'>df.isnull().values.any()</font>

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df['mass'].isnull().value_counts()
# Out:
# True     522
# False    513
# Name: mass, dtype: int64

# %% [markdown]
# ## Bosluklari 0 ile doldurmak

# %%
#df['degisken_adi'].fillna(0, inplace = True)

# %% [markdown]
# ## Bosluklari mean() ile doldurmak

# %%
#df['degisken_adi'].fillna(df.degisken_adi.mean(), inplace = True)

# %% [markdown]
# ## Bosluklarin hepsini kendi ortalamasi ile (mean) doldurmak

# %%
#df.fillna(df.mean(), inplace = True)

# %% [markdown]
# #  <font color='blue'>07) Kategorik Degisken Ozellikleri</font>

# %%
df.head()
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1          269.30  7.10     77.40  2006
# 1  Radial Velocity       1          874.77  2.21     56.95  2008
# 2  Radial Velocity       1          763.00  2.60     19.84  2011
# 3  Radial Velocity       1          326.03 19.40    110.62  2007
# 4  Radial Velocity       1          516.22 10.50    119.47  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   category
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 41.9 KB

# %% [markdown]
# ## 07.01) Sadece Katogerik Degiskenler ve Ozellikleri

# %%
# kat_df = df.select_dtypes('object')   =====> Biz object'i category yaptik

# %%
kat_df = df.select_dtypes('category')
kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %% [markdown]
# ## 07.02) Katogerik Degiskenin Siniflarina ve Sayisina Ulasmak

# %%
kat_df.method.unique()
# Out:
# ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', 'Astrometry', 'Transit Timing Variations', 'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing', 'Pulsation Timing Variations']
# Categories (10, object): ['Astrometry', 'Eclipse Timing Variations', 'Imaging', 'Microlensing', ..., 'Pulsation Timing Variations', 'Radial Velocity', 'Transit', 'Transit Timing Variations']

# %%
kat_df.value_counts().count()
# Out:
# 10

# %% [markdown]
# ## 07.03) Katogerik Degisken Sinifinin Frekanslarina Erismek

# %%
kat_df.value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# dtype: int64

# %%
df['method'].value_counts().plot.barh()   # ===> barh Horizontal (Yatay Grafik)
# Out:
# <AxesSubplot:>

# %%
df['method'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['method'].value_counts().plot.barh(); # ; usteki yaziyi kapatir

# %%
df['year'].value_counts().plot.barh();

# %% [markdown]
# # <font color='blue'>08) Surekli Degisken Ozellikleri</font>

# %%
df_num = df.select_dtypes(include= ['float64', 'int64'])
df_num.head()
# Out:
#    number  orbital_period  mass  distance  year
# 0       1          269.30  7.10     77.40  2006
# 1       1          874.77  2.21     56.95  2008
# 2       1          763.00  2.60     19.84  2011
# 3       1          326.03 19.40    110.62  2007
# 4       1          516.22 10.50    119.47  2009

# %%
df_num.describe().T
# Out:
#                  count    mean      std     min     25%     50%     75%  \
# number         1035.00    1.79     1.24    1.00    1.00    1.00    2.00
# orbital_period  992.00 2002.92 26014.73    0.09    5.44   39.98  526.00
# mass            513.00    2.64     3.82    0.00    0.23    1.26    3.04
# distance        808.00  264.07   733.12    1.35   32.56   55.25  178.50
# year           1035.00 2009.07     3.97 1989.00 2007.00 2010.00 2012.00
#
#                      max
# number              7.00
# orbital_period 730000.00
# mass               25.00
# distance         8500.00
# year             2014.00

# %%
df['distance'].describe()
# Out:
# count    808.00
# mean     264.07
# std      733.12
# min        1.35
# 25%       32.56
# 50%       55.25
# 75%      178.50
# max     8500.00
# Name: distance, dtype: float64

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
print("Ortalama: " + str(df_num["distance"].mean()))
print("Dolu Gözlem Sayısı: " + str(df_num["distance"].count())) 
print("Maksimum Değer: " + str(df_num["distance"].max()))
print("Minimum Değer: " + str(df_num["distance"].min()))
print("Medyan: " + str(df_num["distance"].median()))
print("Standart Sapma: " + str(df_num["distance"].std()))
# Out:
# Ortalama: 264.06928217821786
# Dolu Gözlem Sayısı: 808
# Maksimum Değer: 8500.0
# Minimum Değer: 1.35
# Medyan: 55.25
# Standart Sapma: 733.1164929404422

# %%
print("Ortalama: " , df_num["distance"].mean())
# Out:
# Ortalama:  264.06928217821786

# %% [markdown]
# # Dagilim Grafikleri

# %% [markdown]
# ## Barplot

# %% [markdown]
# **Veri Seti Hikayesi (diamonds)**
#
# price: dolar cinsinde fiyat ($326–$18,823)
#
# carat: ağırlık (0.2–5.01)
#
# cut: kalite (Fair, Good, Very Good, Premium, Ideal)
#
# color: renk (from J (worst) to D (best))
#
# clarity: temizliği, berraklığı (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# x: length in mm (0–10.74)
#
# y: width in mm (0–58.9)
#
# z: depth in mm (0–31.8)
#
# depth: toplam derinlik yüzdesi = z / mean(x, y) = 2 * z / (x + y) (43–79)
#
# table: elmasın en geniş noktasına göre genişliği (43–95)

# %%
diamonds = sns.load_dataset('diamonds')
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price    x    y    z
# 0   0.23    Ideal     E     SI2  61.50  55.00    326 3.95 3.98 2.43
# 1   0.21  Premium     E     SI1  59.80  61.00    326 3.89 3.84 2.31
# 2   0.23     Good     E     VS1  56.90  65.00    327 4.05 4.07 2.31
# 3   0.29  Premium     I     VS2  62.40  58.00    334 4.20 4.23 2.63
# 4   0.31     Good     J     SI2  63.30  58.00    335 4.34 4.35 2.75

# %% [markdown]
# **Veri Setine Hizli Bakis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count    mean     std    min    25%     50%     75%      max
# carat 53940.00    0.80    0.47   0.20   0.40    0.70    1.04     5.01
# depth 53940.00   61.75    1.43  43.00  61.00   61.80   62.50    79.00
# table 53940.00   57.46    2.23  43.00  56.00   57.00   59.00    95.00
# price 53940.00 3932.80 3989.44 326.00 950.00 2401.00 5324.25 18823.00
# x     53940.00    5.73    1.12   0.00   4.71    5.70    6.54    10.74
# y     53940.00    5.73    1.14   0.00   4.72    5.71    6.54    58.90
# z     53940.00    3.54    0.71   0.00   2.91    3.53    4.04    31.80

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price    x    y    z
# 0   0.23    Ideal     E     SI2  61.50  55.00    326 3.95 3.98 2.43
# 1   0.21  Premium     E     SI1  59.80  61.00    326 3.89 3.84 2.31
# 2   0.23     Good     E     VS1  56.90  65.00    327 4.05 4.07 2.31
# 3   0.29  Premium     I     VS2  62.40  58.00    334 4.20 4.23 2.63
# 4   0.31     Good     J     SI2  63.30  58.00    335 4.34 4.35 2.75

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %% [markdown]
# # <font color='red'>Ordinal Tanimlama</font>
# ### <font color='red'>Kategorik Degiskenler ordinal (kendi icinde dereceli) olarak tanitma</font>

# %%
from pandas.api.types import CategoricalDtype

# %%
df.cut = df.cut.astype(CategoricalDtype(categories = ['Fair', 'Good','Very Good', 'Premium', 'Ideal'], ordered = True))
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
# Categories icin liste Tanimlanabilir

cut_kategoriler = ['Fair', 'Good','Very Good', 'Premium', 'Ideal']

df.cut = df.cut.astype(CategoricalDtype(categories = cut_kategoriler, ordered = True))
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %% [markdown]
# # Dagilim Grafikleri

# %% [markdown]
# #### Seaborn Documentation
# #### Example Galery
# #### https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ## Barplot Grafigi

# %%
df['cut'].value_counts().plot.barh();

# %%
df['cut'].value_counts().plot.barh().set_title('Cut Degiskeninin Sinif Frekanslari');

# %%
(df['cut']
 .value_counts()
 .plot.barh()
 .set_title('Cut Degisken Sinif Frekanslari'));

# %% [markdown]
# ## <font color=red>01 - sns.barplot()</font>

# %%
# Cut degisken Frekanslari
sns.barplot(x = 'cut', y = df.cut.index, data = df)
# Out:
# <AxesSubplot:xlabel='cut'>

# %%
sns.barplot(x = 'cut', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.barplot(x = 'cut', y = df.price.index, data = df)
# Out:
# <AxesSubplot:xlabel='cut'>

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price    x    y    z
# 0   0.23    Ideal     E     SI2  61.50  55.00    326 3.95 3.98 2.43
# 1   0.21  Premium     E     SI1  59.80  61.00    326 3.89 3.84 2.31
# 2   0.23     Good     E     VS1  56.90  65.00    327 4.05 4.07 2.31
# 3   0.29  Premium     I     VS2  62.40  58.00    334 4.20 4.23 2.63
# 4   0.31     Good     J     SI2  63.30  58.00    335 4.34 4.35 2.75

# %% [markdown]
# ## hue = ' '
#
# ### Dikey sutunu istenilen degere gore ayristiriyor

# %%
sns.barplot(x = 'cut', y = df.cut.index, data = df, hue = 'color' );

# %% [markdown]
# ## Grafik Ayari
#
# ### Arka Temayi Cizgili Yapmak

# %%
sns.set_theme(style="whitegrid")

# %%
sns.barplot(x = 'cut', y = df.cut.index, data = df, hue = 'color' );

# %% [markdown]
# # Caprazlamalar

# %% [markdown]
# ## <font color=red>02 - sns.catplot()</font>

# %%
sns.catplot(x = 'cut', y = 'price', data = df);

# %%
df.groupby('cut')['price'].describe()
# Out:
#              count    mean     std    min     25%     50%     75%      max
# cut
# Fair       1610.00 4358.76 3560.39 337.00 2050.25 3282.00 5205.50 18574.00
# Good       4906.00 3928.86 3681.59 327.00 1145.00 3050.50 5028.00 18788.00
# Very Good 12082.00 3981.76 3935.86 336.00  912.00 2648.00 5372.75 18818.00
# Premium   13791.00 4584.26 4349.20 326.00 1046.00 3185.00 6296.00 18823.00
# Ideal     21551.00 3457.54 3808.40 326.00  878.00 1810.00 4678.50 18806.00

# %%
sns.barplot(x = 'cut', y = 'price', data = df);

# %% [markdown]
# ## <font color='blue'>hue = ''  Argumani</font>

# %%
sns.barplot(x = 'cut', y = 'price', hue = 'color', data = df);

# %%
# Grafigi Dorulamak

df.groupby(['cut','color'])['price'].mean()
# Out:
# cut        color
# Fair       D       4291.06
#            E       3682.31
#            F       3827.00
#            G       4239.25
#            H       5135.68
#            I       4685.45
#            J       4975.66
# Good       D       3405.38
#            E       3423.64
#            F       3495.75
#            G       4123.48
#            H       4276.25
#            I       5078.53
#            J       4574.17
# Very Good  D       3470.47
#            E       3214.65
#            F       3778.82
#            G       3872.75
#            H       4535.39
#            I       5255.88
#            J       5103.51
# Premium    D       3631.29
#            E       3538.91
#            F       4324.89
#            G       4500.74
#            H       5216.71
#            I       5946.18
#            J       6294.59
# Ideal      D       2629.09
#            E       2597.55
#            F       3374.94
#            G       3720.71
#            H       3889.33
#            I       4451.97
#            J       4918.19
# Name: price, dtype: float64

# %% [markdown]
# # Histogram ve Yogunluk

# %% [markdown]
# ## <font color=red>03 - sns.distplot()</font>

# %%
# Sayisal Degiskenlerin Dagilimi Hakkinda Bilgi

sns.distplot(df.price, kde = False);

# %% [markdown]
# ## kde = True

# %%
sns.distplot(df.price, kde = True );

# %%
sns.displot(df.price, kde = True);

# %% [markdown]
# ## bins = 10

# %%
sns.distplot(df.price, bins = 10);

# %%
sns.distplot(df.price, bins = 200);

# %%
sns.distplot(df.price);

# %% [markdown]
# ## hist = False

# %%
sns.distplot(df.price, hist = False);

# %%
# Grafik Yorumu
# iki tepeli yapi var , carpiklik var demek.

df.price.describe()
# Out:
# count   53940.00
# mean     3932.80
# std      3989.44
# min       326.00
# 25%       950.00
# 50%      2401.00
# 75%      5324.25
# max     18823.00
# Name: price, dtype: float64

# %% [markdown]
# ## <font color=red>04 - sns.kdeplot()</font>

# %%
sns.kdeplot(df.price, shade = True);

# %% [markdown]
# ## <font color=blue>sns.FacetGrid  ====> ust uste grafik gostermek icin></font>

# %%
(sns
 .FacetGrid(df, 
              hue = 'cut',
              height = 5,
              xlim = (0,10000))
.map(sns.kdeplot, 'price', shade = True)
.add_legend()
);

# %%
sns.catplot(x = 'cut', y = 'price', hue = 'color', kind = 'point', data = df );

# %% [markdown]
# # Boxplot

# %% [markdown]
# ## Veri Seti Hikayesi (tips)

# %% [markdown]
# total_bill: yemeğin toplam fiyatı (bahşiş ve vergi dahil)
#
# tip: bahşiş
#
# sex: ücreti ödeyen kişinin cinsiyeti (0=male, 1=female)
#
# smoker: grupta sigara içen var mı? (0=No, 1=Yes)
#
# day: gün (3=Thur, 4=Fri, 5=Sat, 6=Sun)
#
# time: ne zaman? (0=Day, 1=Night)
#
# size: grupta kaç kişi var?

# %%
#virgulden sonra gösterilecek olan sayı 4 basamak olarak ayarlanıyor.
pd.set_option('display.float_format', lambda x: '%.3f' % x)

tips = sns.load_dataset('tips')
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0      16.990 1.010  Female     No  Sun  Dinner     2
# 1      10.340 1.660    Male     No  Sun  Dinner     3
# 2      21.010 3.500    Male     No  Sun  Dinner     3
# 3      23.680 3.310    Male     No  Sun  Dinner     2
# 4      24.590 3.610  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe().T
# Out:
#              count   mean   std   min    25%    50%    75%    max
# total_bill 244.000 19.786 8.902 3.070 13.348 17.795 24.127 50.810
# tip        244.000  2.998 1.384 1.000  2.000  2.900  3.562 10.000
# size       244.000  2.570 0.951 1.000  2.000  2.000  3.000  6.000

# %% [markdown]
# ## Kategorik DEgiskenlerin incelenmesi

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df[['sex', 'day']].value_counts()
# Out:
# sex     day
# Male    Sat     59
#         Sun     58
# Female  Thur    32
# Male    Thur    30
# Female  Sat     28
#         Sun     18
# Male    Fri     10
# Female  Fri      9
# dtype: int64

# %% [markdown]
# ## <font color=red>05 - sns.boxplot()</font>

# %%
sns.boxplot(x = df['total_bill']);

# %%
sns.boxplot(x = df['total_bill'], orient = 'v'); # ===> orient = 'v'  Calismadii!!!!!

# %%
sns.boxplot(y = df['total_bill']);  # vertical yapmak ici y =

# %%
sns.set_theme(style='whitegrid')

# %%
# ?sns.set_theme
# Out:
# Signature:
# sns.set_theme(
#     context='notebook',
#     style='darkgrid',
#     palette='deep',
#     font='sans-serif',
#     font_scale=1,
#     color_codes=True,
#     rc=None,
# )
# Docstring:
# Set aspects of the visual theme for all matplotlib and seaborn plots.
#
# This function changes the global defaults for all plots using the
# :ref:`matplotlib rcParams system <matplotlib:matplotlib-rcparams>`.
# The themeing is decomposed into several distinct sets of parameter values.
#
# The options are illustrated in the :doc:`aesthetics <../tutorial/aesthetics>`
# and :doc:`color palette <../tutorial/color_palettes>` tutorials.
#
# Parameters
# ----------
# context : string or dict
#     Scaling parameters, see :func:`plotting_context`.
# style : string or dict
#     Axes style parameters, see :func:`axes_style`.
# palette : string or sequence
#     Color palette, see :func:`color_palette`.
# font : string
#     Font family, see matplotlib font manager.
# font_scale : float, optional
#     Separate scaling factor to independently scale the size of the
#     font elements.
# color_codes : bool
#     If ``True`` and ``palette`` is a seaborn palette, remap the shorthand
#     color codes (e.g. "b", "g", "r", etc.) to the colors from this palette.
# rc : dict or None
#     Dictionary of rc parameter mappings to override the above.
#
# Examples
# --------
#
# .. include:: ../docstrings/set_theme.rst
# File:      ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/rcmod.py
# Type:      function

# %%
sns.boxplot(y = df['total_bill']);

# %% [markdown]
# # Caprazlamalar

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0      16.990 1.010  Female     No  Sun  Dinner     2
# 1      10.340 1.660    Male     No  Sun  Dinner     3
# 2      21.010 3.500    Male     No  Sun  Dinner     3
# 3      23.680 3.310    Male     No  Sun  Dinner     2
# 4      24.590 3.610  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#              count   mean   std   min    25%    50%    75%    max
# total_bill 244.000 19.786 8.902 3.070 13.348 17.795 24.127 50.810
# tip        244.000  2.998 1.384 1.000  2.000  2.900  3.562 10.000
# size       244.000  2.570 0.951 1.000  2.000  2.000  3.000  6.000

# %%
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ### Soru1) Hangi gunler daha fazla kazaniyoruz ?

# %%
df.pivot_table('total_bill', index='day')
# Out:
#       total_bill
# day
# Thur      17.683
# Fri       17.152
# Sat       20.441
# Sun       21.410

# %%
df.groupby('day')['total_bill'].mean()
# Out:
# day
# Thur   17.683
# Fri    17.152
# Sat    20.441
# Sun    21.410
# Name: total_bill, dtype: float64

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = df);

# %%
# Pazar daha az musteri var ama daha fazla para birakiyor
# Cumartesi en fazla musteri sayisi var

df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# ### Soru2) Sabah mi Aksam mi daha fazla kazaniyoruz ?

# %%
# Aksamlari daha fazla kaziniyoruz

sns.boxplot(x = 'time', y = 'total_bill', data =df);

# %% [markdown]
# ### Soru3) Kisi sayisi ile kazanc arasindaki baglanti nasil ?

# %%
sns.boxplot(x = 'size', y = 'total_bill', data =df);

# %% [markdown]
# ### Soru4) Gun , Kazan ve Cinsiyet Dagilimi nasil ?

# %%
sns.boxplot(x= 'day', y= 'total_bill', hue= 'sex', data= df);

# %%
# Birde cinsiyet ekledim

df.pivot_table('total_bill', index= 'day', columns= 'sex')
# Out:
# sex    Male  Female
# day
# Thur 18.715  16.715
# Fri  19.857  14.146
# Sat  20.803  19.680
# Sun  21.887  19.872

# %% [markdown]
# ### Soru5) Gun, Kazanc ve Zaman Dagilimi

# %%
sns.boxplot(x= 'day', y= 'total_bill', hue= 'time', data= df );

# %% [markdown]
# # Violin Grafigi
#
# ### Boxplot ve Yogunluk karisimi
# ## <font color=red>06 - sns.catplot(x = , kind = 'violin', data =)</font>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0      16.990 1.010  Female     No  Sun  Dinner     2
# 1      10.340 1.660    Male     No  Sun  Dinner     3
# 2      21.010 3.500    Male     No  Sun  Dinner     3
# 3      23.680 3.310    Male     No  Sun  Dinner     2
# 4      24.590 3.610  Female     No  Sun  Dinner     4

# %%
sns.catplot(y= 'total_bill', kind= 'violin', data= df);

# %% [markdown]
# ### Violin Caprazlamalar

# %%
sns.catplot(x= 'day' ,y= 'total_bill', kind= 'violin', data= df);

# %%
sns.catplot(x= 'day' ,y= 'total_bill', hue= 'sex', kind= 'violin', data= df);

# %%
sns.boxplot(x= 'day' ,y= 'total_bill', hue= 'sex', data= df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
rs = np.random.RandomState(8)
type(rs)
# Out:
# numpy.random.mtrand.RandomState

# %% [markdown]
# # Korelasyon Grafikleri
#
# ## <font color=red>07 - sns.scatterplot()</font>

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0      16.990 1.010  Female     No  Sun  Dinner     2
# 1      10.340 1.660    Male     No  Sun  Dinner     3
# 2      21.010 3.500    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', data= df );

# %% [markdown]
# ## Korelasyon Caprazlamalar

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', hue= 'time', data= df);

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', hue= 'time', style= 'time', data= df);

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', hue= 'day', style= 'day', data= df);

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', hue= 'day', style= 'time', data= df);

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', size= 'size', data= df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x= 'total_bill', y= 'tip', hue = 'size', size= 'size', data= df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Dogrusal iliskinin Gosterilmesi
#
# ## <font color=red>08 - sns.lmplot()</font>

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data= df);

# %%
sns.lmplot(x= 'total_bill', y= 'tip', hue= 'smoker', data= df);

# %% [markdown]
# #### col= ''
# #### Kolon ekleme

# %%
sns.lmplot(x= 'total_bill', y= 'tip', hue= 'smoker', col= 'time', data= df);

# %% [markdown]
# #### row= ''
# #### Satir Ekleme

# %%
sns.lmplot(x= 'total_bill', y= 'tip', hue= 'smoker', col= 'time', row= 'sex',data= df);

# %% [markdown]
# # Scatterplot Matrisi
#
# ## <font color=red>09 - sns.pairplot()</font>

# %%
iris = sns.load_dataset('iris')
df = iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0         5.100        3.500         1.400        0.200  setosa
# 1         4.900        3.000         1.400        0.200  setosa
# 2         4.700        3.200         1.300        0.200  setosa
# 3         4.600        3.100         1.500        0.200  setosa
# 4         5.000        3.600         1.400        0.200  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df);

# %%
sns.pairplot(df, hue= 'species');

# %%
sns.pairplot(df, hue= 'species', markers= ['o', 's', 'D']);

# %%
sns.pairplot(df, kind = 'reg');

# %%
sns.pairplot(df, kind= 'reg', hue= 'species');

# %% [markdown]
# # Heatmap
#
# ### (Zamansal inceleme veya cok sinifli kategorik degisken inceleme)

# %% [markdown]
# ## <font color=red>10 - sns.heatmap()</font>

# %%
flights = sns.load_dataset('flights')
df = flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df.passengers.describe()
# Out:
# count   144.000
# mean    280.299
# std     119.966
# min     104.000
# 25%     180.000
# 50%     265.500
# 75%     360.500
# max     622.000
# Name: passengers, dtype: float64

# %%
# Dikkat Pivot_table DEgilllll, pivot yapiyoruz
# df.pivot(index= , column= , 'values')

df1 = df.pivot('month', 'year', 'passengers')
df1
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(df1);

# %%
sns.heatmap(df1, annot= True, fmt= 'd');

# %%
sns.heatmap(df1, annot= True ,fmt= 'd', linewidths= .5 );

# %%
sns.heatmap(df1, annot= True, fmt= 'd', linewidths= .5, cbar= False);

# %% [markdown]
# # Cizgi Grafik
#
# ## Veri Seti 'fmri'

# %%
#virgulden sonra gösterilecek olan sayı 6 basamak olarak ayarlanıyor.
pd.set_option('display.float_format', lambda x: '%.6f' % x)


fmri = sns.load_dataset('fmri')
df = fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# Beyne baglanan cihaz araciligili ile toplanan sinaylleri ifade eden bir veri seti
# Subject = verilerin toplandigi kisileri ifade eder
# Time point = zaman nokatlari 
# Event = Farkli olaylar
# Region = Sinayilin toplandigi bolgeyi ifade ediyor
# Signal = gelen Signal

# Nesnelerin interneti verilerine beziyor.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
df.shape
# Out:
# (1064, 5)

# %%
df['timepoint'].describe()
# Out:
# count   1064.000000
# mean       9.000000
# std        5.479801
# min        0.000000
# 25%        4.000000
# 50%        9.000000
# 75%       14.000000
# max       18.000000
# Name: timepoint, dtype: float64

# %%
df['signal'].describe()
# Out:
# count   1064.000000
# mean       0.003540
# std        0.093930
# min       -0.255486
# 25%       -0.046070
# 50%       -0.013653
# 75%        0.024293
# max        0.564985
# Name: signal, dtype: float64

# %%
df.groupby('timepoint')['signal'].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby('signal').count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
# 0.455575         1          1      1       1
# 0.460896         1          1      1       1
# 0.476055         1          1      1       1
# 0.494787         1          1      1       1
# 0.564985         1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby('timepoint')['signal'].describe()
# Out:
#               count      mean      std       min       25%       50%  \
# timepoint
# 0         56.000000 -0.016662 0.028326 -0.064454 -0.039169 -0.018382
# 1         56.000000 -0.025002 0.030641 -0.082174 -0.046299 -0.024533
# 2         56.000000 -0.012873 0.035440 -0.110565 -0.034944 -0.013183
# 3         56.000000  0.034446 0.058260 -0.089708 -0.001157  0.028430
# 4         56.000000  0.098194 0.092838 -0.046347  0.030912  0.070166
# 5         56.000000  0.137725 0.123353 -0.017946  0.042762  0.096535
# 6         56.000000  0.127515 0.137332 -0.054405  0.022409  0.068850
# 7         56.000000  0.075660 0.129704 -0.108222 -0.016252  0.032486
# 8         56.000000  0.013420 0.104216 -0.181241 -0.049453 -0.012834
# 9         56.000000 -0.032041 0.072728 -0.152929 -0.075693 -0.038496
# 10        56.000000 -0.053685 0.053148 -0.176453 -0.078893 -0.052906
# 11        56.000000 -0.058194 0.053828 -0.238474 -0.093127 -0.045699
# 12        56.000000 -0.052526 0.056991 -0.255486 -0.090391 -0.042294
# 13        56.000000 -0.043532 0.053598 -0.224351 -0.069285 -0.031612
# 14        56.000000 -0.033660 0.045983 -0.169312 -0.055110 -0.022165
# 15        56.000000 -0.025880 0.039092 -0.134828 -0.050536 -0.018207
# 16        56.000000 -0.022414 0.035035 -0.131641 -0.041122 -0.020777
# 17        56.000000 -0.021368 0.034797 -0.121574 -0.042946 -0.017070
# 18        56.000000 -0.021867 0.036322 -0.103513 -0.046781 -0.020225
#
#                 75%      max
# timepoint
# 0          0.003539 0.074399
# 1         -0.005388 0.063558
# 2          0.009318 0.077277
# 3          0.061840 0.185581
# 4          0.144911 0.346775
# 5          0.211638 0.476055
# 6          0.218919 0.564985
# 7          0.144781 0.494787
# 8          0.030396 0.337143
# 9          0.008717 0.221716
# 10        -0.015302 0.089231
# 11        -0.022522 0.030528
# 12        -0.016239 0.055766
# 13        -0.012958 0.059510
# 14        -0.006797 0.050133
# 15         0.000486 0.047102
# 16        -0.001380 0.057105
# 17        -0.000026 0.073757
# 18        -0.002821 0.090520

# %% [markdown]
# # Cizgi Grafik ve Capralamalar
#
# ## <font color=red>11 - sns.lineplot()</font>

# %%
sns.lineplot(x= 'timepoint', y= 'signal', data= df);

# %%
sns.lineplot(x= 'timepoint', y= 'signal', hue= 'event', data= df);

# %%
df['event'].value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
sns.lineplot(x= 'timepoint', y= 'signal', hue= 'region', data= df);

# %%
df.region.value_counts()
# Out:
# parietal    532
# frontal     532
# Name: region, dtype: int64

# %%
sns.lineplot(x= 'timepoint', y= 'signal', hue= 'region', style='region', data= df);

# %%
sns.lineplot(x= 'timepoint',
             y= 'signal',
             hue= 'event',
             style= 'event',
             markers= True, dashes= False, data= df);

# %%
sns.lineplot(x= 'timepoint',
             y= 'signal',
             hue= 'region',
             style= 'event',
             data= df);

# %% [markdown]
# # Basit Zaman Serisi Grafigi

# %%
# !pip install pandas_datareader
import pandas_datareader as pr
# Out:
# Requirement already satisfied: pandas_datareader in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: pandas>=0.23 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from pandas_datareader) (1.3.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from pandas_datareader) (2.26.0)
# Requirement already satisfied: lxml in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: numpy>=1.17.3 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas_datareader) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/macbook/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)

# %%
#df = pr.get_data_yahoo('AAPL', start= '2016-01-01', end= '2019-08-25')
#df.head()
#SSLError: HTTPSConnectionPool(host='finance.yahoo.com', port=443): Max retries exceeded with url: /quote/AAPL/history?period1=1451617200&period2=1566784799&interval=1d&frequency=1d&filter=history (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1125)')))

# %%
#virgulden sonra gösterilecek olan sayı 6 basamak olarak ayarlanıyor.
pd.set_option('display.float_format', lambda x: '%.2f' % x)

from datetime import datetime

taxi = sns.load_dataset('taxis')
df = taxi.copy()
df.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare  tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60  7.00 2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79  5.00 0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37  7.50 2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70 27.00 6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16  9.00 1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0   0.00  12.95  yellow  credit card        Lenox Hill West
# 1   0.00   9.30  yellow         cash  Upper West Side South
# 2   0.00  14.16  yellow  credit card          Alphabet City
# 3   0.00  36.95  yellow  credit card              Hudson Sq
# 4   0.00  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %% [markdown]
# ## Kolon DateTime donusumu

# %%
#Asagidaki aciklamada ====> dtype: datetime64[ns] oldu

df['pickup'] = pd.DatetimeIndex(df['pickup'])
df.pickup.head()
# Out:
# 0   2019-03-23 20:21:09
# 1   2019-03-04 16:11:55
# 2   2019-03-27 17:53:01
# 3   2019-03-10 01:23:59
# 4   2019-03-30 13:27:42
# Name: pickup, dtype: datetime64[ns]

# %%
alis_zamani_total = df[['pickup', 'total']]

# %%
alis_zamani_total.head()
# Out:
#                pickup  total
# 0 2019-03-23 20:21:09  12.95
# 1 2019-03-04 16:11:55   9.30
# 2 2019-03-27 17:53:01  14.16
# 3 2019-03-10 01:23:59  36.95
# 4 2019-03-30 13:27:42  13.40

# %% [markdown]
# ## Kolon zaman Donusum , Saat silindi Yil,Ay,Gun kaldi

# %%
alis_zamani_total.pickup = alis_zamani_total.pickup.dt.date
alis_zamani_total.pickup.head(2)
# Out:
# 0    2019-03-23
# 1    2019-03-04
# Name: pickup, dtype: object

# %%
#Kolon index olarak atandi =====> df.set_index('pickup')   da olurdu

alis_zamani_total.index = alis_zamani_total.pickup
alis_zamani_total.drop('pickup', axis= 1, inplace= True)
alis_zamani_total.head(2)
# Out:
#             total
# pickup
# 2019-03-23  12.95
# 2019-03-04   9.30

# %%
# Dikkat Saat silinince object oldu kolon, bu yuzden tekrar DateTime Donusumu yapildi

alis_zamani_total.index = pd.DatetimeIndex(alis_zamani_total.index)

# %%
alis_zamani_total.index
# Out:
# DatetimeIndex(['2019-03-23', '2019-03-04', '2019-03-27', '2019-03-10',
#                '2019-03-30', '2019-03-11', '2019-03-26', '2019-03-22',
#                '2019-03-23', '2019-03-08',
#                ...
#                '2019-03-12', '2019-03-30', '2019-03-07', '2019-03-28',
#                '2019-03-23', '2019-03-31', '2019-03-31', '2019-03-23',
#                '2019-03-04', '2019-03-13'],
#               dtype='datetime64[ns]', name='pickup', length=6433, freq=None)

# %%
alis_zamani_total.head()
# Out:
#             total
# pickup
# 2019-03-23  12.95
# 2019-03-04   9.30
# 2019-03-27  14.16
# 2019-03-10  36.95
# 2019-03-30  13.40

# %% [markdown]
# # <font color='red'>12 - df.plot</font>

# %%
alis_zamani_total.plot();
